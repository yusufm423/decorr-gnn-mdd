# %%
import os
import scipy.io
import numpy as np
import random
import pandas as pd
import torch
from Utils import compute_KNN_graph, fisher_z_transform, create_graph, to_tensor, create_graph_sliding_window
from sklearn.model_selection import train_test_split
from torch_geometric.data import InMemoryDataset, Data
from torch_geometric.utils import dense_to_sparse
import torch.nn.functional as func
import torch.optim as optim
from torch_geometric.loader import DataLoader
from torch_geometric.nn import GCNConv, global_mean_pool
from torch_geometric.nn import GATConv, ChebConv
import torch.nn as nn
from collections import Counter
import os.path as osp
import csv
from sklearn.metrics import roc_auc_score
from sklearn.model_selection import StratifiedKFold
from sklearn.metrics import accuracy_score, f1_score, recall_score, confusion_matrix
from sklearn.model_selection import StratifiedKFold, StratifiedShuffleSplit

# %%
seed=89
atlas_name= "AAL"
dataset_name = "MDDvHC"


if atlas_name == "AAL":
    start = 0
    end = 116
elif atlas_name == "Craddock":
    start = 228
    end = 428
elif atlas_name == "Dosenbach":
    start = 1408
    end = 1568
else:
    exit()

# %%
# Function to set seed
def set_seed(seed):
    random.seed(seed)
    np.random.seed(seed)
    torch.manual_seed(seed)
    if torch.cuda.is_available():
        torch.cuda.manual_seed(seed)
        torch.cuda.manual_seed_all(seed)
    torch.backends.cudnn.deterministic = True
    torch.backends.cudnn.benchmark = False
    torch.use_deterministic_algorithms(True)

# Environment variables for reproducibility
os.environ['PYTHONHASHSEED'] = str(seed)
os.environ['CUBLAS_WORKSPACE_CONFIG'] = ':4096:8'
os.environ['CUDA_LAUNCH_BLOCKING'] = '1'

# Set your seed
set_seed(seed)

def seed_worker(worker_id):
    worker_seed = torch.initial_seed() % 2**32
    numpy.random.seed(worker_seed)
    random.seed(worker_seed)

g = torch.Generator()
g.manual_seed(0)

# %%
from sklearn.preprocessing import StandardScaler

def normalize(matrix):
    scaler = StandardScaler()
    normalized_matrix = scaler.fit_transform(matrix)
    return normalized_matrix

# %%
#sliding window
def create_graph_sliding_window_demographics(X, D, Y, start, end, region=True):
    S = 30 # Sliding Step
    T = 60 # Window Size

    X_adjgraph=[]
    X_featgraph = []
    Y_list = []
    num_samples_per_subject = []

    for i in range(len(Y)):
        #select rows according to atlas
        # bold_matrix = X[i][start:end,:]
        bold_matrix = X[i]
        n = bold_matrix.shape[0]
        demog = D[i]
        # Unsqueeze and expand the demog array to create a 116x4 matrix
        demog_expanded = np.expand_dims(demog, axis=0)  # Shape (1, 3)
        demog_expanded = np.repeat(demog_expanded, n, axis=0)  # Shape (116, 3)
        
        temp_y = Y[i]

        num_rows, num_cols = bold_matrix.shape
        num_samples = 0
        for start_idx in range(0, num_cols - T + 1, S):
            end_idx = start_idx + T
            if end_idx <= num_cols:
                
                if region == True:
                    window_data =  bold_matrix[:, start_idx:end_idx]    #RxR
                else:
                    window_data =  np.transpose(bold_matrix[:, start_idx:end_idx])  #TxT

                window_data1 = np.corrcoef(window_data)
                correlation_matrix_fisher = fisher_z_transform(window_data1)
                correlation_matrix_fisher = np.around(correlation_matrix_fisher, 8)     #upto 8 decimal points
                # Concatenate the demog_expanded with correlation_matrix_fisher along the column
                result_matrix = np.concatenate((correlation_matrix_fisher, demog_expanded), axis=1)

                
                knn_graph = compute_KNN_graph(correlation_matrix_fisher)

                if region == True:
                    X_featgraph.append(result_matrix)
                else:
                    X_featgraph.append(window_data)
                    
                X_adjgraph.append(knn_graph)
                Y_list.append(temp_y)
                num_samples = num_samples+1
            
        num_samples_per_subject.append(num_samples)


    return X_featgraph, X_adjgraph, Y_list, num_samples_per_subject

# %%
def create_graph_demographics(X, D, Y, start, end, region=True):
    X_adjgraph=[]
    X_featgraph = []

    for i in range(len(Y)):
        if region == True:
            # bold_matrix = X[i][start:end,:] #RxR
            bold_matrix = X[i] #RxR
        else:
            bold_matrix = np.transpose(X[i][start:end,:]) #TxT

        n= bold_matrix.shape[0]
        # Unsqueeze and expand the demog array to create a 116x4 matrix
        demog_expanded = np.expand_dims(D[i], axis=0)  # Shape (1, 3)
        demog_expanded = np.repeat(demog_expanded, n, axis=0)  # Shape (116, 3)
        
        window_data1 = np.corrcoef(bold_matrix)
        correlation_matrix_fisher = fisher_z_transform(window_data1)
        correlation_matrix_fisher = np.around(correlation_matrix_fisher, 8)
        knn_graph = compute_KNN_graph(correlation_matrix_fisher)
        # Concatenate the demog_expanded with correlation_matrix_fisher along the column
        result_matrix = np.concatenate((correlation_matrix_fisher, demog_expanded), axis=1)

        if region == True:
            X_featgraph.append(result_matrix)
        else:
            X_featgraph.append(bold_matrix)
            
        X_adjgraph.append(knn_graph)

    return X_featgraph, X_adjgraph, Y

# %%
#final model 


import torch
import torch.nn as nn
import torch.nn.functional as F
from torch_geometric.nn import ChebConv, global_mean_pool,GATConv



class SkipConnModel(nn.Module):
    def __init__(self, num_features_R, num_classes, k_order, dropout_prob=0.5):
        super(SkipConnModel, self).__init__()
        self.dropout_prob = dropout_prob
        
        self.num_layers = 6
        self.convs = nn.ModuleList()  # List for model 1
        self.bns = nn.ModuleList()    # BatchNorm for model 1
        
        # Define the first GCN model
        self.convs.append(ChebConv(num_features_R, 128, K=3, normalization='sym'))
        self.bns.append(nn.BatchNorm1d(128))
        
        self.convs.append(ChebConv(128, 128, K=3, normalization='sym'))
        self.bns.append(nn.BatchNorm1d(128))

        self.convs.append(ChebConv(128, 128, K=3, normalization='sym'))
        self.bns.append(nn.BatchNorm1d(128))
        
        # self.convs.append(ChebConv(128, 128, K=3, normalization='sym'))
        # self.bns.append(nn.BatchNorm1d(128))
        
        self.out_fc = nn.Linear(128, num_classes)
        self.weights = torch.nn.Parameter(torch.randn(len(self.convs)))
        # Add the decov weight as a parameter
        #self.current_decov_weight = nn.Parameter(torch.tensor(1.0))


    def reset_parameters(self):
        for conv in self.convs:
            conv.reset_parameters()
        for bn in self.bns:
            bn.reset_parameters()
        self.out_fc.reset_parameters()
        torch.nn.init.normal_(self.weights)

    def forward(self, data_R):
        # First GCN model
        x1, edge_index1, edge_attr1 = data_R.x, data_R.edge_index, data_R.edge_attr
        batch1 = data_R.batch
        
        layer_out1 = []  # List to store the outputs of model 1
        x1 = self.convs[0](x1, edge_index1, edge_attr1)
        x1 = self.bns[0](x1)
        x1 = F.relu(x1, inplace=True)
        layer_out1.append(x1)
        x1 = F.dropout(x1, p=self.dropout_prob, training=self.training)
        
                          
        x1 = self.convs[1](x1, edge_index1, edge_attr1)
        x1 = self.bns[1](x1)
        x1 = F.relu(x1, inplace=True)
        x1 = x1 + 0.8 * layer_out1[0]
        layer_out1.append(x1)
        x1 = F.dropout(x1, p=self.dropout_prob, training=self.training) 
        
                          
        x1 = self.convs[2](x1, edge_index1, edge_attr1)
        x1 = self.bns[2](x1)
        x1 = F.relu(x1, inplace=True)
        x1 = x1 + 0.8 * layer_out1[1]
        layer_out1.append(x1)
        # x1 = F.dropout(x1, p=self.dropout_prob, training=self.training) 


        # x1 = self.convs[3](x1, edge_index1, edge_attr1)
        # x1 = self.bns[3](x1)
        # x1 = F.relu(x1, inplace=True)
        # x1 = x1 + 1 * layer_out1[2]
        # layer_out1.append(x1)
        #x1 = F.dropout(x1, p=self.dropout_prob, training=self.training) 
        

        # Apply softmax to the weights
        weight = F.softmax(self.weights, dim=0)
        
        # Multiply each layer output by its corresponding weight
        weighted_outs = [layer_out1[i] * weight[i] for i in range(len(layer_out1))]
        
        # Sum the weighted outputs to get the final embedding
        emb = sum(weighted_outs)
        
        # Apply global mean pooling on the summed weighted outputs
        pooled_emb = global_mean_pool(emb, batch1)

        # Pass the final pooled embedding through the linear layer
        x = self.out_fc(pooled_emb)
        
        return x, pooled_emb

# %%
import torch

def DECOV(embeddings):
    # Transpose the embeddings
    embeddings_t = embeddings.T  # Now it's 32 x batch

    # Compute the covariance matrix along the columns
    C = torch.cov(embeddings_t)  # Only works with PyTorch 1.9.0 or later

    # Frobenius norm of the covariance matrix
    C_fro_norm = torch.norm(C, p='fro')

    # Diagonal elements of the covariance matrix
    diag_elements = torch.diag(C,0)

    # L2 norm of the diagonal elements
    C2_l2norm_diag = torch.norm(diag_elements)

    # DeCov loss
    L_DECOV = (C_fro_norm ** 2) - (C2_l2norm_diag ** 2)

    return L_DECOV

# %%
def GCN_train(loader):
    model.train()

    pred = []
    label = []
    loss_all = 0

    for data in loader:
        data = data.to(device)
        optimizer.zero_grad()
        output, pooled = model(data)  # Get both output and embeddings

         #Ensure pooled_emb is on the correct device for DECOV
        output = output.to('cpu')
        loss_decov = DECOV(output)
        loss_decov = loss_decov.to(device)  # Move loss_decov back to the GPU if needed

        output = output.to(device)  # Move back to the original device if needed
        
        loss1 = func.cross_entropy(output, data.y) 
        
        loss = loss1 + 1e-12*loss_decov
        #loss=loss1
        loss.backward()
        loss_all += data.num_graphs * loss.item()
        optimizer.step()

        pred.append(func.softmax(output, dim=1).max(dim=1)[1])
        label.append(data.y)
   
    y_pred = torch.cat(pred, dim=0).cpu().detach().numpy()
    y_true = torch.cat(label, dim=0).cpu().detach().numpy()
    tn, fp, fn, tp = confusion_matrix(y_true, y_pred).ravel()

    epoch_sen = tp / (tp + fn)
    epoch_spe = tn / (tn + fp)
    epoch_acc = (tn + tp) / (tn + tp + fn + fp)
    f1 = f1_score(y_true, y_pred)

    return epoch_sen, epoch_spe, epoch_acc, f1, loss_all/len(loader)


def GCN_test(loader):
    model.eval()

    pred = []
    scores = []
    label = []
    loss_all = 0
    for data in loader:
        data = data.to(device)
        output , pooled= model(data)
        
        output = output.to('cpu')
        loss_decov = DECOV(output)
        loss_decov = loss_decov.to(device)  # Move loss_decov back to the GPU if needed

        output = output.to(device)  # Move back to the original device if needed
        
        loss1 = func.cross_entropy(output, data.y)
        loss = loss1 + 1e-12*loss_decov
        loss_all += data.num_graphs * loss.item()
   
        softmax_output = func.softmax(output, dim=1)
        scores.append(softmax_output[:, 1])  # Collect the scores for the positive class
        pred.append(softmax_output.max(dim=1)[1])
        label.append(data.y)

    y_pred = torch.cat(pred, dim=0).cpu().detach().numpy()
    y_scores = torch.cat(scores, dim=0).cpu().detach().numpy()
    y_true = torch.cat(label, dim=0).cpu().detach().numpy()
    
    tn, fp, fn, tp = confusion_matrix(y_true, y_pred).ravel()
    epoch_sen = tp / (tp + fn)
    epoch_spe = tn / (tn + fp)
    epoch_acc = (tn + tp) / (tn + tp + fn + fp)
    epoch_f1 = f1_score(y_true, y_pred)
    epoch_auc = roc_auc_score(y_true, y_scores)  # Use scores instead of predicted labels
    return epoch_sen, epoch_spe, epoch_acc, epoch_f1, epoch_auc,loss_all / len(loader)

# %%
X_new =  np.load(f'/home/jyoti/Sliding_window/Experiments_final/{dataset_name}/{atlas_name}/X.npz')
X_loaded = [X_new[key] for key in X_new.files]
X_loaded = [normalize(matrix) for matrix in X_loaded]

print(X_loaded[0].shape)

Y_loaded = np.load(f'/home/jyoti/Sliding_window/Experiments_final/{dataset_name}/{atlas_name}/Y.npy')
print(Y_loaded)

# Load the CSV file
demographic_data = pd.read_csv(f'/home/jyoti/Sliding_window/Experiments_final/{dataset_name}/{atlas_name}/demographics_data.csv')

# Convert demographic data to tensor
# Assuming the columns are ['subject_id', 'age', 'edu', 'motion', 'sex']
demographics = demographic_data[['Age', 'Edu', 'Sex']].values
# Out:
# (116, 200)
# [1 1 1 ... 0 0 0]

# %%
pwd
# Out:
# '/home/jyoti/Sliding_window/Experiments_final/Ablation_new'

# %%
print(len(X_loaded))
print(len(Y_loaded))
# Out:
# 1570
# 1570

# %%
skf = StratifiedKFold(n_splits=10, shuffle=True, random_state=seed)
device = torch.device('cpu')
eval_metrics1 = np.zeros((skf.n_splits, 5))
eval_metrics2 = np.zeros((skf.n_splits, 5))
eval_metrics3 = np.zeros((skf.n_splits, 5))
eval_metrics4 = np.zeros((skf.n_splits, 5))

dataset = X_loaded
labels = Y_loaded

# %%
dataset[0].shape
# Out:
# (116, 200)

# %%
# Assuming skf is defined as an instance of StratifiedKFold
for n_fold, (train_val, test) in enumerate(skf.split(dataset, labels)):

    model = SkipConnModel((end - start + 3), 2,3).to(device)
    optimizer = torch.optim.Adam(model.parameters(), lr=0.001, weight_decay=5e-4)

    # Split dataset, labels, and demographics into train/validation and test sets
    train_val_dataset = [dataset[i] for i in train_val]
    test_dataset = [dataset[i] for i in test]
    train_val_labels = labels[train_val]
    test_labels = labels[test]
    train_val_demographics = demographics[train_val]
    test_demographics = demographics[test]

    # Create index array for train_val_dataset
    train_val_index = np.arange(len(train_val_dataset))

    # Split train_val into train and validation sets
    train_idx, val_idx, _, _ = train_test_split(
        train_val_index,
        train_val_labels,
        test_size=0.1,
        shuffle=True,
        stratify=train_val_labels, 
        random_state=seed
    )

    train_dataset = [train_val_dataset[i] for i in train_idx]
    val_dataset = [train_val_dataset[i] for i in val_idx]
    train_labels = [train_val_labels[i] for i in train_idx]
    val_labels = [train_val_labels[i] for i in val_idx]
    train_demographics = [train_val_demographics[i] for i in train_idx]
    val_demographics = [train_val_demographics[i] for i in val_idx]

    X_train_featgraph, X_train_adjgraph, Y_train, _ = create_graph_sliding_window_demographics(train_dataset, train_demographics, train_labels, start, end, region=True)
    X_val_featgraph, X_val_adjgraph, Y_val = create_graph_demographics(val_dataset, val_demographics, val_labels, start, end, region=True)
    X_test_featgraph, X_test_adjgraph, Y_test = create_graph_demographics(test_dataset, test_demographics, test_labels, start, end, region=True)

    X_train_datalist = to_tensor(X_train_featgraph, X_train_adjgraph, Y_train)
    X_val_datalist = to_tensor(X_val_featgraph, X_val_adjgraph, Y_val)
    X_test_datalist = to_tensor(X_test_featgraph, X_test_adjgraph, Y_test)

    if(len(X_train_datalist)%32==1):
        batch = 31
    else:
        batch = 32

    train_loader = DataLoader(X_train_datalist, batch_size=batch, shuffle=True, num_workers=0, worker_init_fn=seed_worker, generator=g)
    val_loader = DataLoader(X_val_datalist, batch_size=32, shuffle=True, num_workers=0, worker_init_fn=seed_worker, generator=g)
    test_loader = DataLoader(X_test_datalist, batch_size=32, shuffle=True, num_workers=0, worker_init_fn=seed_worker, generator=g)

    min_v_loss1 = np.inf
    best_val_acc1 = 0
    best_test_acc1 = 0
    best_test_f11 = 0
    best_test_sen1 = 0
    best_test_spe1 = 0
    best_test_auc1 = 0

    best_test_acc2 = 0
    best_test_f12 = 0
    best_test_sen2 = 0
    best_test_spe2 = 0
    best_test_auc2 = 0

    best_val_acc3 = 0
    best_test_acc3 = 0
    best_test_f13 = 0
    best_test_sen3 = 0
    best_test_spe3 = 0
    best_test_auc3 = 0

    best_val_auc4 = 0
    best_test_acc4 = 0
    best_test_f14 = 0
    best_test_sen4 = 0
    best_test_spe4 = 0
    best_test_auc4 = 0
    for epoch in range(50):
        _, _, _, _, t_loss = GCN_train(train_loader)
        val_sen, val_spe, val_acc,val_f1, val_auc, v_loss = GCN_test(val_loader)
        test_sen, test_spe, test_acc,test_f1, test_auc, _ = GCN_test(test_loader)


        if min_v_loss1 > v_loss:
            min_v_loss1 = v_loss
            best_val_acc1 = val_acc
            best_test_f11 = test_f1
            best_test_sen1, best_test_spe1, best_test_acc1, best_test_auc1 = test_sen, test_spe, test_acc, test_auc
            # torch.save(model.state_dict(), 'SW_LANCET_results/model_min_vloss/best_model_%02i.pth' % (n_fold+1))
        
        if test_acc > best_test_acc2:  # Check if current test accuracy is better than the best recorded
            best_test_acc2 = test_acc
            best_test_f12 = test_f1
            best_test_sen2, best_test_spe2,best_test_auc2 = test_sen, test_spe, test_auc
            # torch.save(model.state_dict(), 'SW_LANCET_results/model_max_test_acc/best_model_%02i.pth' % (n_fold+1))
        
        if val_acc > best_val_acc3:
            best_val_acc3 = val_acc
            best_test_f13 = test_f1
            best_test_sen3, best_test_spe3, best_test_acc3, best_test_auc3 = test_sen, test_spe, test_acc, test_auc
            # Define the directory path
            # model_dir = f'Ours_Model/{dataset_name}/{atlas_name}/'
            # # Create the directory if it does not exist
            # os.makedirs(model_dir, exist_ok=True)

            # torch.save(model.state_dict(), f'{model_dir}/best_model_%02i.pth' % (n_fold+1))
        
        if val_auc > best_val_auc4:
            best_val_auc4 = val_auc
            best_test_f14 = test_f1
            best_test_sen4, best_test_spe4, best_test_acc4, best_test_auc4 = test_sen, test_spe, test_acc, test_auc
            
        print('CV: {:03d}, Epoch: {:03d}, Val Loss: {:.5f}, Val ACC: {:.5f},Val AUC: {:.5f}, Test ACC: {:.5f}, Test F1: {:.5f}, TEST SPE: {:.5f}, '
                  'TEST SEN: {:.5f}, TEST AUC: {:.5f}'.format(n_fold +1, epoch + 1, v_loss, val_acc, val_auc, test_acc,test_f1,
                                        test_spe,test_sen, test_auc))
            
    eval_metrics1[n_fold, 0] = best_test_sen1
    eval_metrics1[n_fold, 1] = best_test_spe1
    eval_metrics1[n_fold, 2] = best_test_acc1
    eval_metrics1[n_fold, 3] = best_test_f11
    eval_metrics1[n_fold, 4] = best_test_auc1

    eval_metrics2[n_fold, 0] = best_test_sen2
    eval_metrics2[n_fold, 1] = best_test_spe2
    eval_metrics2[n_fold, 2] = best_test_acc2
    eval_metrics2[n_fold, 3] = best_test_f12
    eval_metrics2[n_fold, 4] = best_test_auc2

    eval_metrics3[n_fold, 0] = best_test_sen3
    eval_metrics3[n_fold, 1] = best_test_spe3
    eval_metrics3[n_fold, 2] = best_test_acc3
    eval_metrics3[n_fold, 3] = best_test_f13
    eval_metrics3[n_fold, 4] = best_test_auc3
        
    eval_metrics4[n_fold, 0] = best_test_sen4
    eval_metrics4[n_fold, 1] = best_test_spe4
    eval_metrics4[n_fold, 2] = best_test_acc4
    eval_metrics4[n_fold, 3] = best_test_f14
    eval_metrics4[n_fold, 4] = best_test_auc4
# Out:
# CV: 001, Epoch: 001, Val Loss: 16.74726, Val ACC: 0.71831,Val AUC: 0.76948, Test ACC: 0.61783, Test F1: 0.68085, TEST SPE: 0.44000, TEST SEN: 0.78049, TEST AUC: 0.64862
# CV: 001, Epoch: 002, Val Loss: 16.11673, Val ACC: 0.73239,Val AUC: 0.79452, Test ACC: 0.63694, Test F1: 0.69841, TEST SPE: 0.45333, TEST SEN: 0.80488, TEST AUC: 0.67122
# CV: 001, Epoch: 003, Val Loss: 15.10120, Val ACC: 0.76056,Val AUC: 0.82492, Test ACC: 0.63057, Test F1: 0.68132, TEST SPE: 0.49333, TEST SEN: 0.75610, TEST AUC: 0.68520
# CV: 001, Epoch: 004, Val Loss: 16.05330, Val ACC: 0.69014,Val AUC: 0.80743, Test ACC: 0.63057, Test F1: 0.71000, TEST SPE: 0.37333, TEST SEN: 0.86585, TEST AUC: 0.68016
# CV: 001, Epoch: 005, Val Loss: 15.02713, Val ACC: 0.76761,Val AUC: 0.81558, Test ACC: 0.63694, Test F1: 0.66667, TEST SPE: 0.57333, TEST SEN: 0.69512, TEST AUC: 0.68260
# CV: 001, Epoch: 006, Val Loss: 16.56324, Val ACC: 0.66197,Val AUC: 0.81995, Test ACC: 0.58599, Test F1: 0.69484, TEST SPE: 0.24000, TEST SEN: 0.90244, TEST AUC: 0.68553
# CV: 001, Epoch: 007, Val Loss: 17.57781, Val ACC: 0.66901,Val AUC: 0.78140, Test ACC: 0.64968, Test F1: 0.60993, TEST SPE: 0.78667, TEST SEN: 0.52439, TEST AUC: 0.69187
# CV: 001, Epoch: 008, Val Loss: 33.55947, Val ACC: 0.61972,Val AUC: 0.75556, Test ACC: 0.53503, Test F1: 0.30476, TEST SPE: 0.90667, TEST SEN: 0.19512, TEST AUC: 0.61171
# CV: 001, Epoch: 009, Val Loss: 47.44418, Val ACC: 0.52817,Val AUC: 0.74881, Test ACC: 0.53503, Test F1: 0.69198, TEST SPE: 0.02667, TEST SEN: 1.00000, TEST AUC: 0.73837
# CV: 001, Epoch: 010, Val Loss: 15.08716, Val ACC: 0.73944,Val AUC: 0.82134, Test ACC: 0.61146, Test F1: 0.67027, TEST SPE: 0.45333, TEST SEN: 0.75610, TEST AUC: 0.68260
# CV: 001, Epoch: 011, Val Loss: 27.37324, Val ACC: 0.61972,Val AUC: 0.68760, Test ACC: 0.64331, Test F1: 0.71717, TEST SPE: 0.40000, TEST SEN: 0.86585, TEST AUC: 0.68114
# CV: 001, Epoch: 012, Val Loss: 39.53221, Val ACC: 0.61972,Val AUC: 0.68025, Test ACC: 0.62420, Test F1: 0.70647, TEST SPE: 0.36000, TEST SEN: 0.86585, TEST AUC: 0.65805
# CV: 001, Epoch: 013, Val Loss: 22.99189, Val ACC: 0.61972,Val AUC: 0.79511, Test ACC: 0.60510, Test F1: 0.50000, TEST SPE: 0.85333, TEST SEN: 0.37805, TEST AUC: 0.71431
# CV: 001, Epoch: 014, Val Loss: 35.20163, Val ACC: 0.61972,Val AUC: 0.72317, Test ACC: 0.61146, Test F1: 0.70531, TEST SPE: 0.30667, TEST SEN: 0.89024, TEST AUC: 0.67967
# CV: 001, Epoch: 015, Val Loss: 18.82113, Val ACC: 0.69718,Val AUC: 0.76649, Test ACC: 0.58599, Test F1: 0.65608, TEST SPE: 0.40000, TEST SEN: 0.75610, TEST AUC: 0.66146
# CV: 001, Epoch: 016, Val Loss: 40.45311, Val ACC: 0.57746,Val AUC: 0.75040, Test ACC: 0.52229, Test F1: 0.24242, TEST SPE: 0.93333, TEST SEN: 0.14634, TEST AUC: 0.64016
# CV: 001, Epoch: 017, Val Loss: 28.73714, Val ACC: 0.59859,Val AUC: 0.69058, Test ACC: 0.52866, Test F1: 0.56471, TEST SPE: 0.46667, TEST SEN: 0.58537, TEST AUC: 0.59089
# CV: 001, Epoch: 018, Val Loss: 43.51558, Val ACC: 0.51408,Val AUC: 0.77166, Test ACC: 0.53503, Test F1: 0.69198, TEST SPE: 0.02667, TEST SEN: 1.00000, TEST AUC: 0.66780
# CV: 001, Epoch: 019, Val Loss: 48.68010, Val ACC: 0.54225,Val AUC: 0.68462, Test ACC: 0.54140, Test F1: 0.69492, TEST SPE: 0.04000, TEST SEN: 1.00000, TEST AUC: 0.67268
# CV: 001, Epoch: 020, Val Loss: 35.47571, Val ACC: 0.57746,Val AUC: 0.67548, Test ACC: 0.54777, Test F1: 0.51701, TEST SPE: 0.64000, TEST SEN: 0.46341, TEST AUC: 0.64081
# CV: 001, Epoch: 021, Val Loss: 33.38692, Val ACC: 0.61268,Val AUC: 0.72635, Test ACC: 0.53503, Test F1: 0.29126, TEST SPE: 0.92000, TEST SEN: 0.18293, TEST AUC: 0.68488
# CV: 001, Epoch: 022, Val Loss: 23.89345, Val ACC: 0.65493,Val AUC: 0.73808, Test ACC: 0.60510, Test F1: 0.67021, TEST SPE: 0.42667, TEST SEN: 0.76829, TEST AUC: 0.64537
# CV: 001, Epoch: 023, Val Loss: 54.14212, Val ACC: 0.54225,Val AUC: 0.68164, Test ACC: 0.55414, Test F1: 0.70085, TEST SPE: 0.06667, TEST SEN: 1.00000, TEST AUC: 0.70211
# CV: 001, Epoch: 024, Val Loss: 84.14006, Val ACC: 0.51408,Val AUC: 0.80763, Test ACC: 0.47134, Test F1: 0.02353, TEST SPE: 0.97333, TEST SEN: 0.01220, TEST AUC: 0.68407
# CV: 001, Epoch: 025, Val Loss: 36.71908, Val ACC: 0.59155,Val AUC: 0.62540, Test ACC: 0.60510, Test F1: 0.66304, TEST SPE: 0.45333, TEST SEN: 0.74390, TEST AUC: 0.63415
# CV: 001, Epoch: 026, Val Loss: 22.30274, Val ACC: 0.69014,Val AUC: 0.75397, Test ACC: 0.63057, Test F1: 0.62821, TEST SPE: 0.66667, TEST SEN: 0.59756, TEST AUC: 0.65138
# CV: 001, Epoch: 027, Val Loss: 27.21964, Val ACC: 0.72535,Val AUC: 0.77126, Test ACC: 0.63057, Test F1: 0.61842, TEST SPE: 0.69333, TEST SEN: 0.57317, TEST AUC: 0.69837
# CV: 001, Epoch: 028, Val Loss: 63.22036, Val ACC: 0.57042,Val AUC: 0.69058, Test ACC: 0.49045, Test F1: 0.16667, TEST SPE: 0.92000, TEST SEN: 0.09756, TEST AUC: 0.64488
# CV: 001, Epoch: 029, Val Loss: 25.33200, Val ACC: 0.66197,Val AUC: 0.76014, Test ACC: 0.63057, Test F1: 0.68132, TEST SPE: 0.49333, TEST SEN: 0.75610, TEST AUC: 0.66650
# CV: 001, Epoch: 030, Val Loss: 38.14695, Val ACC: 0.55634,Val AUC: 0.66176, Test ACC: 0.63057, Test F1: 0.65882, TEST SPE: 0.57333, TEST SEN: 0.68293, TEST AUC: 0.66667
# CV: 001, Epoch: 031, Val Loss: 41.72387, Val ACC: 0.59859,Val AUC: 0.67051, Test ACC: 0.56688, Test F1: 0.54667, TEST SPE: 0.64000, TEST SEN: 0.50000, TEST AUC: 0.64163
# CV: 001, Epoch: 032, Val Loss: 55.67550, Val ACC: 0.54930,Val AUC: 0.62619, Test ACC: 0.50955, Test F1: 0.52174, TEST SPE: 0.50667, TEST SEN: 0.51220, TEST AUC: 0.52748
# CV: 001, Epoch: 033, Val Loss: 34.30507, Val ACC: 0.57042,Val AUC: 0.65302, Test ACC: 0.53503, Test F1: 0.56805, TEST SPE: 0.48000, TEST SEN: 0.58537, TEST AUC: 0.56504
# CV: 001, Epoch: 034, Val Loss: 26.21762, Val ACC: 0.67606,Val AUC: 0.76252, Test ACC: 0.62420, Test F1: 0.59310, TEST SPE: 0.73333, TEST SEN: 0.52439, TEST AUC: 0.69545
# CV: 001, Epoch: 035, Val Loss: 24.73028, Val ACC: 0.61972,Val AUC: 0.70509, Test ACC: 0.59873, Test F1: 0.65946, TEST SPE: 0.44000, TEST SEN: 0.74390, TEST AUC: 0.61252
# CV: 001, Epoch: 036, Val Loss: 24.70935, Val ACC: 0.63380,Val AUC: 0.74921, Test ACC: 0.59873, Test F1: 0.57718, TEST SPE: 0.68000, TEST SEN: 0.52439, TEST AUC: 0.67268
# CV: 001, Epoch: 037, Val Loss: 42.41426, Val ACC: 0.61268,Val AUC: 0.70330, Test ACC: 0.56051, Test F1: 0.67606, TEST SPE: 0.21333, TEST SEN: 0.87805, TEST AUC: 0.61902
# CV: 001, Epoch: 038, Val Loss: 39.07572, Val ACC: 0.61268,Val AUC: 0.74006, Test ACC: 0.53503, Test F1: 0.34234, TEST SPE: 0.86667, TEST SEN: 0.23171, TEST AUC: 0.67724
# CV: 001, Epoch: 039, Val Loss: 21.03830, Val ACC: 0.66901,Val AUC: 0.75556, Test ACC: 0.66242, Test F1: 0.69364, TEST SPE: 0.58667, TEST SEN: 0.73171, TEST AUC: 0.67805
# CV: 001, Epoch: 040, Val Loss: 27.86094, Val ACC: 0.68310,Val AUC: 0.73669, Test ACC: 0.57325, Test F1: 0.62570, TEST SPE: 0.45333, TEST SEN: 0.68293, TEST AUC: 0.66000
# CV: 001, Epoch: 041, Val Loss: 54.25293, Val ACC: 0.55634,Val AUC: 0.75020, Test ACC: 0.54777, Test F1: 0.69787, TEST SPE: 0.05333, TEST SEN: 1.00000, TEST AUC: 0.68211
# CV: 001, Epoch: 042, Val Loss: 49.12835, Val ACC: 0.57746,Val AUC: 0.71741, Test ACC: 0.61783, Test F1: 0.72727, TEST SPE: 0.22667, TEST SEN: 0.97561, TEST AUC: 0.67252
# CV: 001, Epoch: 043, Val Loss: 26.73641, Val ACC: 0.68310,Val AUC: 0.71741, Test ACC: 0.63694, Test F1: 0.68852, TEST SPE: 0.49333, TEST SEN: 0.76829, TEST AUC: 0.64959
# CV: 001, Epoch: 044, Val Loss: 80.32682, Val ACC: 0.50704,Val AUC: 0.67190, Test ACC: 0.54140, Test F1: 0.69492, TEST SPE: 0.04000, TEST SEN: 1.00000, TEST AUC: 0.69325
# CV: 001, Epoch: 045, Val Loss: 37.90651, Val ACC: 0.62676,Val AUC: 0.74424, Test ACC: 0.61783, Test F1: 0.72222, TEST SPE: 0.25333, TEST SEN: 0.95122, TEST AUC: 0.71919
# CV: 001, Epoch: 046, Val Loss: 45.17956, Val ACC: 0.52113,Val AUC: 0.71622, Test ACC: 0.59236, Test F1: 0.71429, TEST SPE: 0.17333, TEST SEN: 0.97561, TEST AUC: 0.69154
# CV: 001, Epoch: 047, Val Loss: 41.25918, Val ACC: 0.62676,Val AUC: 0.73390, Test ACC: 0.56051, Test F1: 0.47328, TEST SPE: 0.76000, TEST SEN: 0.37805, TEST AUC: 0.65382
# CV: 001, Epoch: 048, Val Loss: 45.21686, Val ACC: 0.61972,Val AUC: 0.71165, Test ACC: 0.59236, Test F1: 0.70909, TEST SPE: 0.20000, TEST SEN: 0.95122, TEST AUC: 0.66520
# CV: 001, Epoch: 049, Val Loss: 48.54972, Val ACC: 0.60563,Val AUC: 0.66832, Test ACC: 0.59236, Test F1: 0.67677, TEST SPE: 0.34667, TEST SEN: 0.81707, TEST AUC: 0.64984
# CV: 001, Epoch: 050, Val Loss: 72.34679, Val ACC: 0.57746,Val AUC: 0.75735, Test ACC: 0.50318, Test F1: 0.15217, TEST SPE: 0.96000, TEST SEN: 0.08537, TEST AUC: 0.65382
# CV: 002, Epoch: 001, Val Loss: 18.13224, Val ACC: 0.60563,Val AUC: 0.67528, Test ACC: 0.65605, Test F1: 0.72727, TEST SPE: 0.41333, TEST SEN: 0.87805, TEST AUC: 0.70992
# CV: 002, Epoch: 002, Val Loss: 19.17107, Val ACC: 0.60563,Val AUC: 0.66455, Test ACC: 0.61146, Test F1: 0.67725, TEST SPE: 0.42667, TEST SEN: 0.78049, TEST AUC: 0.71805
# CV: 002, Epoch: 003, Val Loss: 19.05119, Val ACC: 0.61972,Val AUC: 0.74344, Test ACC: 0.61146, Test F1: 0.49587, TEST SPE: 0.88000, TEST SEN: 0.36585, TEST AUC: 0.72683
# CV: 002, Epoch: 004, Val Loss: 20.46271, Val ACC: 0.58451,Val AUC: 0.63911, Test ACC: 0.64331, Test F1: 0.70833, TEST SPE: 0.44000, TEST SEN: 0.82927, TEST AUC: 0.71545
# CV: 002, Epoch: 005, Val Loss: 21.46700, Val ACC: 0.61268,Val AUC: 0.66912, Test ACC: 0.64331, Test F1: 0.73077, TEST SPE: 0.33333, TEST SEN: 0.92683, TEST AUC: 0.74033
# CV: 002, Epoch: 006, Val Loss: 20.13848, Val ACC: 0.62676,Val AUC: 0.65441, Test ACC: 0.64968, Test F1: 0.71204, TEST SPE: 0.45333, TEST SEN: 0.82927, TEST AUC: 0.73984
# CV: 002, Epoch: 007, Val Loss: 18.68476, Val ACC: 0.61268,Val AUC: 0.69555, Test ACC: 0.69427, Test F1: 0.71429, TEST SPE: 0.65333, TEST SEN: 0.73171, TEST AUC: 0.74439
# CV: 002, Epoch: 008, Val Loss: 25.94056, Val ACC: 0.55634,Val AUC: 0.68203, Test ACC: 0.58599, Test F1: 0.39252, TEST SPE: 0.94667, TEST SEN: 0.25610, TEST AUC: 0.74618
# CV: 002, Epoch: 009, Val Loss: 33.78715, Val ACC: 0.61972,Val AUC: 0.59976, Test ACC: 0.60510, Test F1: 0.71560, TEST SPE: 0.22667, TEST SEN: 0.95122, TEST AUC: 0.67122
# CV: 002, Epoch: 010, Val Loss: 18.34501, Val ACC: 0.65493,Val AUC: 0.72774, Test ACC: 0.66242, Test F1: 0.67081, TEST SPE: 0.66667, TEST SEN: 0.65854, TEST AUC: 0.75561
# CV: 002, Epoch: 011, Val Loss: 28.57980, Val ACC: 0.60563,Val AUC: 0.64845, Test ACC: 0.62420, Test F1: 0.70936, TEST SPE: 0.34667, TEST SEN: 0.87805, TEST AUC: 0.70667
# CV: 002, Epoch: 012, Val Loss: 23.66809, Val ACC: 0.57746,Val AUC: 0.67150, Test ACC: 0.67516, Test F1: 0.66225, TEST SPE: 0.74667, TEST SEN: 0.60976, TEST AUC: 0.72634
# CV: 002, Epoch: 013, Val Loss: 39.02718, Val ACC: 0.52817,Val AUC: 0.77325, Test ACC: 0.55414, Test F1: 0.28571, TEST SPE: 0.97333, TEST SEN: 0.17073, TEST AUC: 0.76000
# CV: 002, Epoch: 014, Val Loss: 30.89355, Val ACC: 0.56338,Val AUC: 0.75477, Test ACC: 0.57962, Test F1: 0.36538, TEST SPE: 0.96000, TEST SEN: 0.23171, TEST AUC: 0.74699
# CV: 002, Epoch: 015, Val Loss: 33.50087, Val ACC: 0.56338,Val AUC: 0.65620, Test ACC: 0.59236, Test F1: 0.53623, TEST SPE: 0.74667, TEST SEN: 0.45122, TEST AUC: 0.67659
# CV: 002, Epoch: 016, Val Loss: 22.02296, Val ACC: 0.65493,Val AUC: 0.71343, Test ACC: 0.70064, Test F1: 0.70064, TEST SPE: 0.73333, TEST SEN: 0.67073, TEST AUC: 0.73268
# CV: 002, Epoch: 017, Val Loss: 31.92881, Val ACC: 0.54225,Val AUC: 0.76530, Test ACC: 0.56688, Test F1: 0.34615, TEST SPE: 0.94667, TEST SEN: 0.21951, TEST AUC: 0.77171
# CV: 002, Epoch: 018, Val Loss: 34.68484, Val ACC: 0.57746,Val AUC: 0.71741, Test ACC: 0.59873, Test F1: 0.70968, TEST SPE: 0.22667, TEST SEN: 0.93902, TEST AUC: 0.74114
# CV: 002, Epoch: 019, Val Loss: 26.78939, Val ACC: 0.61268,Val AUC: 0.72556, Test ACC: 0.60510, Test F1: 0.46552, TEST SPE: 0.90667, TEST SEN: 0.32927, TEST AUC: 0.70309
# CV: 002, Epoch: 020, Val Loss: 35.14713, Val ACC: 0.61268,Val AUC: 0.67727, Test ACC: 0.62420, Test F1: 0.71220, TEST SPE: 0.33333, TEST SEN: 0.89024, TEST AUC: 0.73008
# CV: 002, Epoch: 021, Val Loss: 23.95798, Val ACC: 0.62676,Val AUC: 0.71641, Test ACC: 0.65605, Test F1: 0.59091, TEST SPE: 0.85333, TEST SEN: 0.47561, TEST AUC: 0.75415
# CV: 002, Epoch: 022, Val Loss: 22.83432, Val ACC: 0.67606,Val AUC: 0.71602, Test ACC: 0.63694, Test F1: 0.69841, TEST SPE: 0.45333, TEST SEN: 0.80488, TEST AUC: 0.72878
# CV: 002, Epoch: 023, Val Loss: 33.30851, Val ACC: 0.59859,Val AUC: 0.67369, Test ACC: 0.61783, Test F1: 0.70588, TEST SPE: 0.33333, TEST SEN: 0.87805, TEST AUC: 0.71626
# CV: 002, Epoch: 024, Val Loss: 91.25898, Val ACC: 0.48592,Val AUC: 0.78219, Test ACC: 0.47771, Test F1: 0.04651, TEST SPE: 0.97333, TEST SEN: 0.02439, TEST AUC: 0.72163
# CV: 002, Epoch: 025, Val Loss: 64.93471, Val ACC: 0.55634,Val AUC: 0.68502, Test ACC: 0.54140, Test F1: 0.69231, TEST SPE: 0.05333, TEST SEN: 0.98780, TEST AUC: 0.70862
# CV: 002, Epoch: 026, Val Loss: 62.93969, Val ACC: 0.55634,Val AUC: 0.59519, Test ACC: 0.62420, Test F1: 0.69110, TEST SPE: 0.42667, TEST SEN: 0.80488, TEST AUC: 0.64390
# CV: 002, Epoch: 027, Val Loss: 38.31814, Val ACC: 0.61268,Val AUC: 0.69614, Test ACC: 0.64331, Test F1: 0.58824, TEST SPE: 0.81333, TEST SEN: 0.48780, TEST AUC: 0.73398
# CV: 002, Epoch: 028, Val Loss: 37.85052, Val ACC: 0.56338,Val AUC: 0.67727, Test ACC: 0.61783, Test F1: 0.52381, TEST SPE: 0.85333, TEST SEN: 0.40244, TEST AUC: 0.71301
# CV: 002, Epoch: 029, Val Loss: 48.04431, Val ACC: 0.57746,Val AUC: 0.71324, Test ACC: 0.56051, Test F1: 0.31683, TEST SPE: 0.96000, TEST SEN: 0.19512, TEST AUC: 0.65008
# CV: 002, Epoch: 030, Val Loss: 32.44601, Val ACC: 0.59859,Val AUC: 0.72595, Test ACC: 0.63694, Test F1: 0.53659, TEST SPE: 0.89333, TEST SEN: 0.40244, TEST AUC: 0.75415
# CV: 002, Epoch: 031, Val Loss: 49.66451, Val ACC: 0.59859,Val AUC: 0.69515, Test ACC: 0.57325, Test F1: 0.40708, TEST SPE: 0.89333, TEST SEN: 0.28049, TEST AUC: 0.64195
# CV: 002, Epoch: 032, Val Loss: 24.29367, Val ACC: 0.66197,Val AUC: 0.74165, Test ACC: 0.64331, Test F1: 0.65000, TEST SPE: 0.65333, TEST SEN: 0.63415, TEST AUC: 0.72407
# CV: 002, Epoch: 033, Val Loss: 28.98968, Val ACC: 0.61268,Val AUC: 0.68740, Test ACC: 0.64331, Test F1: 0.66667, TEST SPE: 0.60000, TEST SEN: 0.68293, TEST AUC: 0.72423
# CV: 002, Epoch: 034, Val Loss: 68.23633, Val ACC: 0.52113,Val AUC: 0.61367, Test ACC: 0.51592, Test F1: 0.28302, TEST SPE: 0.88000, TEST SEN: 0.18293, TEST AUC: 0.64797
# CV: 002, Epoch: 035, Val Loss: 35.75535, Val ACC: 0.58451,Val AUC: 0.65004, Test ACC: 0.61783, Test F1: 0.61538, TEST SPE: 0.65333, TEST SEN: 0.58537, TEST AUC: 0.68049
# CV: 002, Epoch: 036, Val Loss: 25.33834, Val ACC: 0.64085,Val AUC: 0.71562, Test ACC: 0.68790, Test F1: 0.71676, TEST SPE: 0.61333, TEST SEN: 0.75610, TEST AUC: 0.75740
# CV: 002, Epoch: 037, Val Loss: 48.25692, Val ACC: 0.57746,Val AUC: 0.65521, Test ACC: 0.56688, Test F1: 0.68519, TEST SPE: 0.20000, TEST SEN: 0.90244, TEST AUC: 0.68472
# CV: 002, Epoch: 038, Val Loss: 30.35338, Val ACC: 0.61268,Val AUC: 0.70727, Test ACC: 0.65605, Test F1: 0.70330, TEST SPE: 0.52000, TEST SEN: 0.78049, TEST AUC: 0.74634
# CV: 002, Epoch: 039, Val Loss: 37.15377, Val ACC: 0.62676,Val AUC: 0.67786, Test ACC: 0.63057, Test F1: 0.71287, TEST SPE: 0.36000, TEST SEN: 0.87805, TEST AUC: 0.69317
# CV: 002, Epoch: 040, Val Loss: 27.48030, Val ACC: 0.66197,Val AUC: 0.75855, Test ACC: 0.66242, Test F1: 0.60741, TEST SPE: 0.84000, TEST SEN: 0.50000, TEST AUC: 0.75154
# CV: 002, Epoch: 041, Val Loss: 61.40956, Val ACC: 0.56338,Val AUC: 0.71373, Test ACC: 0.54777, Test F1: 0.69264, TEST SPE: 0.08000, TEST SEN: 0.97561, TEST AUC: 0.74179
# CV: 002, Epoch: 042, Val Loss: 65.17619, Val ACC: 0.52817,Val AUC: 0.62579, Test ACC: 0.55414, Test F1: 0.35185, TEST SPE: 0.90667, TEST SEN: 0.23171, TEST AUC: 0.64179
# CV: 002, Epoch: 043, Val Loss: 26.61177, Val ACC: 0.66901,Val AUC: 0.73331, Test ACC: 0.70064, Test F1: 0.67586, TEST SPE: 0.81333, TEST SEN: 0.59756, TEST AUC: 0.74602
# CV: 002, Epoch: 044, Val Loss: 58.04179, Val ACC: 0.57746,Val AUC: 0.67309, Test ACC: 0.55414, Test F1: 0.67890, TEST SPE: 0.17333, TEST SEN: 0.90244, TEST AUC: 0.70439
# CV: 002, Epoch: 045, Val Loss: 27.84216, Val ACC: 0.65493,Val AUC: 0.71443, Test ACC: 0.65605, Test F1: 0.63014, TEST SPE: 0.76000, TEST SEN: 0.56098, TEST AUC: 0.75089
# CV: 002, Epoch: 046, Val Loss: 43.78029, Val ACC: 0.60563,Val AUC: 0.71224, Test ACC: 0.59236, Test F1: 0.44828, TEST SPE: 0.89333, TEST SEN: 0.31707, TEST AUC: 0.67659
# CV: 002, Epoch: 047, Val Loss: 49.49040, Val ACC: 0.53521,Val AUC: 0.62639, Test ACC: 0.57962, Test F1: 0.58750, TEST SPE: 0.58667, TEST SEN: 0.57317, TEST AUC: 0.66276
# CV: 002, Epoch: 048, Val Loss: 62.51766, Val ACC: 0.59859,Val AUC: 0.60076, Test ACC: 0.65605, Test F1: 0.71579, TEST SPE: 0.46667, TEST SEN: 0.82927, TEST AUC: 0.64423
# CV: 002, Epoch: 049, Val Loss: 56.75241, Val ACC: 0.64789,Val AUC: 0.67409, Test ACC: 0.63057, Test F1: 0.72381, TEST SPE: 0.30667, TEST SEN: 0.92683, TEST AUC: 0.70390
# CV: 002, Epoch: 050, Val Loss: 71.89447, Val ACC: 0.55634,Val AUC: 0.62679, Test ACC: 0.56688, Test F1: 0.44262, TEST SPE: 0.82667, TEST SEN: 0.32927, TEST AUC: 0.60618
# CV: 003, Epoch: 001, Val Loss: 17.78277, Val ACC: 0.60563,Val AUC: 0.71204, Test ACC: 0.67516, Test F1: 0.67925, TEST SPE: 0.69333, TEST SEN: 0.65854, TEST AUC: 0.73496
# CV: 003, Epoch: 002, Val Loss: 17.72042, Val ACC: 0.60563,Val AUC: 0.72854, Test ACC: 0.63057, Test F1: 0.59722, TEST SPE: 0.74667, TEST SEN: 0.52439, TEST AUC: 0.73756
# CV: 003, Epoch: 003, Val Loss: 20.47919, Val ACC: 0.59859,Val AUC: 0.74503, Test ACC: 0.54777, Test F1: 0.31068, TEST SPE: 0.93333, TEST SEN: 0.19512, TEST AUC: 0.65740
# CV: 003, Epoch: 004, Val Loss: 17.71300, Val ACC: 0.71127,Val AUC: 0.73847, Test ACC: 0.68153, Test F1: 0.75000, TEST SPE: 0.42667, TEST SEN: 0.91463, TEST AUC: 0.73691
# CV: 003, Epoch: 005, Val Loss: 17.21138, Val ACC: 0.66901,Val AUC: 0.73986, Test ACC: 0.72611, Test F1: 0.73292, TEST SPE: 0.73333, TEST SEN: 0.71951, TEST AUC: 0.75837
# CV: 003, Epoch: 006, Val Loss: 17.88200, Val ACC: 0.70423,Val AUC: 0.75099, Test ACC: 0.65605, Test F1: 0.73000, TEST SPE: 0.40000, TEST SEN: 0.89024, TEST AUC: 0.72276
# CV: 003, Epoch: 007, Val Loss: 35.10391, Val ACC: 0.49296,Val AUC: 0.74603, Test ACC: 0.49045, Test F1: 0.06977, TEST SPE: 0.98667, TEST SEN: 0.03659, TEST AUC: 0.63285
# CV: 003, Epoch: 008, Val Loss: 24.03004, Val ACC: 0.52817,Val AUC: 0.75894, Test ACC: 0.52866, Test F1: 0.22917, TEST SPE: 0.96000, TEST SEN: 0.13415, TEST AUC: 0.71431
# CV: 003, Epoch: 009, Val Loss: 30.89061, Val ACC: 0.51408,Val AUC: 0.74364, Test ACC: 0.51592, Test F1: 0.13636, TEST SPE: 1.00000, TEST SEN: 0.07317, TEST AUC: 0.64146
# CV: 003, Epoch: 010, Val Loss: 31.27026, Val ACC: 0.64789,Val AUC: 0.64944, Test ACC: 0.64331, Test F1: 0.72816, TEST SPE: 0.34667, TEST SEN: 0.91463, TEST AUC: 0.69659
# CV: 003, Epoch: 011, Val Loss: 19.01453, Val ACC: 0.66197,Val AUC: 0.75855, Test ACC: 0.63057, Test F1: 0.54688, TEST SPE: 0.85333, TEST SEN: 0.42683, TEST AUC: 0.73577
# CV: 003, Epoch: 012, Val Loss: 25.07376, Val ACC: 0.59859,Val AUC: 0.78498, Test ACC: 0.57325, Test F1: 0.70222, TEST SPE: 0.14667, TEST SEN: 0.96341, TEST AUC: 0.73285
# CV: 003, Epoch: 013, Val Loss: 23.19769, Val ACC: 0.63380,Val AUC: 0.75656, Test ACC: 0.62420, Test F1: 0.72811, TEST SPE: 0.25333, TEST SEN: 0.96341, TEST AUC: 0.72846
# CV: 003, Epoch: 014, Val Loss: 19.95163, Val ACC: 0.68310,Val AUC: 0.77226, Test ACC: 0.56688, Test F1: 0.44262, TEST SPE: 0.82667, TEST SEN: 0.32927, TEST AUC: 0.67837
# CV: 003, Epoch: 015, Val Loss: 42.96082, Val ACC: 0.59859,Val AUC: 0.64924, Test ACC: 0.63057, Test F1: 0.72381, TEST SPE: 0.30667, TEST SEN: 0.92683, TEST AUC: 0.70813
# CV: 003, Epoch: 016, Val Loss: 31.07361, Val ACC: 0.61268,Val AUC: 0.75159, Test ACC: 0.58599, Test F1: 0.71111, TEST SPE: 0.16000, TEST SEN: 0.97561, TEST AUC: 0.73886
# CV: 003, Epoch: 017, Val Loss: 24.17179, Val ACC: 0.59155,Val AUC: 0.72158, Test ACC: 0.61783, Test F1: 0.52381, TEST SPE: 0.85333, TEST SEN: 0.40244, TEST AUC: 0.72520
# CV: 003, Epoch: 018, Val Loss: 35.28514, Val ACC: 0.57042,Val AUC: 0.66534, Test ACC: 0.62420, Test F1: 0.57554, TEST SPE: 0.77333, TEST SEN: 0.48780, TEST AUC: 0.71154
# CV: 003, Epoch: 019, Val Loss: 38.74786, Val ACC: 0.64085,Val AUC: 0.64448, Test ACC: 0.64331, Test F1: 0.70833, TEST SPE: 0.44000, TEST SEN: 0.82927, TEST AUC: 0.73772
# CV: 003, Epoch: 020, Val Loss: 23.34306, Val ACC: 0.64085,Val AUC: 0.68919, Test ACC: 0.59873, Test F1: 0.63158, TEST SPE: 0.53333, TEST SEN: 0.65854, TEST AUC: 0.60634
# CV: 003, Epoch: 021, Val Loss: 38.78637, Val ACC: 0.53521,Val AUC: 0.72774, Test ACC: 0.55414, Test F1: 0.30000, TEST SPE: 0.96000, TEST SEN: 0.18293, TEST AUC: 0.77008
# CV: 003, Epoch: 022, Val Loss: 27.96654, Val ACC: 0.64085,Val AUC: 0.66793, Test ACC: 0.64968, Test F1: 0.68571, TEST SPE: 0.56000, TEST SEN: 0.73171, TEST AUC: 0.74715
# CV: 003, Epoch: 023, Val Loss: 49.08158, Val ACC: 0.59859,Val AUC: 0.66017, Test ACC: 0.63057, Test F1: 0.73394, TEST SPE: 0.25333, TEST SEN: 0.97561, TEST AUC: 0.73919
# CV: 003, Epoch: 024, Val Loss: 27.07347, Val ACC: 0.62676,Val AUC: 0.72337, Test ACC: 0.63057, Test F1: 0.53226, TEST SPE: 0.88000, TEST SEN: 0.40244, TEST AUC: 0.75106
# CV: 003, Epoch: 025, Val Loss: 40.16778, Val ACC: 0.61268,Val AUC: 0.69833, Test ACC: 0.53503, Test F1: 0.30476, TEST SPE: 0.90667, TEST SEN: 0.19512, TEST AUC: 0.58813
# CV: 003, Epoch: 026, Val Loss: 53.84318, Val ACC: 0.55634,Val AUC: 0.63474, Test ACC: 0.64968, Test F1: 0.68208, TEST SPE: 0.57333, TEST SEN: 0.71951, TEST AUC: 0.68163
# CV: 003, Epoch: 027, Val Loss: 69.52129, Val ACC: 0.50704,Val AUC: 0.73251, Test ACC: 0.49682, Test F1: 0.11236, TEST SPE: 0.97333, TEST SEN: 0.06098, TEST AUC: 0.68439
# CV: 003, Epoch: 028, Val Loss: 26.78215, Val ACC: 0.59859,Val AUC: 0.71184, Test ACC: 0.52866, Test F1: 0.38333, TEST SPE: 0.80000, TEST SEN: 0.28049, TEST AUC: 0.63220
# CV: 003, Epoch: 029, Val Loss: 34.63034, Val ACC: 0.61972,Val AUC: 0.68919, Test ACC: 0.69427, Test F1: 0.70000, TEST SPE: 0.70667, TEST SEN: 0.68293, TEST AUC: 0.77528
# CV: 003, Epoch: 030, Val Loss: 50.78309, Val ACC: 0.57746,Val AUC: 0.65163, Test ACC: 0.62420, Test F1: 0.71770, TEST SPE: 0.30667, TEST SEN: 0.91463, TEST AUC: 0.73333
# CV: 003, Epoch: 031, Val Loss: 63.24690, Val ACC: 0.62676,Val AUC: 0.63096, Test ACC: 0.63694, Test F1: 0.71357, TEST SPE: 0.38667, TEST SEN: 0.86585, TEST AUC: 0.71553
# CV: 003, Epoch: 032, Val Loss: 36.62742, Val ACC: 0.59155,Val AUC: 0.64010, Test ACC: 0.61146, Test F1: 0.65922, TEST SPE: 0.49333, TEST SEN: 0.71951, TEST AUC: 0.67740
# CV: 003, Epoch: 033, Val Loss: 53.32907, Val ACC: 0.58451,Val AUC: 0.66216, Test ACC: 0.61783, Test F1: 0.71963, TEST SPE: 0.26667, TEST SEN: 0.93902, TEST AUC: 0.70366
# CV: 003, Epoch: 034, Val Loss: 64.54654, Val ACC: 0.58451,Val AUC: 0.64736, Test ACC: 0.59236, Test F1: 0.70909, TEST SPE: 0.20000, TEST SEN: 0.95122, TEST AUC: 0.72423
# CV: 003, Epoch: 035, Val Loss: 32.57566, Val ACC: 0.61268,Val AUC: 0.69495, Test ACC: 0.63694, Test F1: 0.58394, TEST SPE: 0.80000, TEST SEN: 0.48780, TEST AUC: 0.71512
# CV: 003, Epoch: 036, Val Loss: 41.36820, Val ACC: 0.61268,Val AUC: 0.73072, Test ACC: 0.56051, Test F1: 0.37838, TEST SPE: 0.89333, TEST SEN: 0.25610, TEST AUC: 0.70195
# CV: 003, Epoch: 037, Val Loss: 71.46817, Val ACC: 0.59155,Val AUC: 0.62281, Test ACC: 0.60510, Test F1: 0.71560, TEST SPE: 0.22667, TEST SEN: 0.95122, TEST AUC: 0.68341
# CV: 003, Epoch: 038, Val Loss: 55.47010, Val ACC: 0.59859,Val AUC: 0.63474, Test ACC: 0.63694, Test F1: 0.72464, TEST SPE: 0.33333, TEST SEN: 0.91463, TEST AUC: 0.70341
# CV: 003, Epoch: 039, Val Loss: 59.79353, Val ACC: 0.57746,Val AUC: 0.69535, Test ACC: 0.48408, Test F1: 0.14737, TEST SPE: 0.92000, TEST SEN: 0.08537, TEST AUC: 0.60748
# CV: 003, Epoch: 040, Val Loss: 63.54402, Val ACC: 0.58451,Val AUC: 0.69654, Test ACC: 0.57325, Test F1: 0.70742, TEST SPE: 0.12000, TEST SEN: 0.98780, TEST AUC: 0.69415
# CV: 003, Epoch: 041, Val Loss: 36.21931, Val ACC: 0.64085,Val AUC: 0.73768, Test ACC: 0.64331, Test F1: 0.71717, TEST SPE: 0.40000, TEST SEN: 0.86585, TEST AUC: 0.73675
# CV: 003, Epoch: 042, Val Loss: 45.03680, Val ACC: 0.57746,Val AUC: 0.66395, Test ACC: 0.67516, Test F1: 0.70175, TEST SPE: 0.61333, TEST SEN: 0.73171, TEST AUC: 0.72276
# CV: 003, Epoch: 043, Val Loss: 41.06942, Val ACC: 0.66197,Val AUC: 0.72178, Test ACC: 0.52229, Test F1: 0.29907, TEST SPE: 0.88000, TEST SEN: 0.19512, TEST AUC: 0.63805
# CV: 003, Epoch: 044, Val Loss: 38.84298, Val ACC: 0.61972,Val AUC: 0.66673, Test ACC: 0.64968, Test F1: 0.67836, TEST SPE: 0.58667, TEST SEN: 0.70732, TEST AUC: 0.74341
# CV: 003, Epoch: 045, Val Loss: 61.47797, Val ACC: 0.57746,Val AUC: 0.67468, Test ACC: 0.64331, Test F1: 0.74074, TEST SPE: 0.28000, TEST SEN: 0.97561, TEST AUC: 0.74341
# CV: 003, Epoch: 046, Val Loss: 23.56316, Val ACC: 0.70423,Val AUC: 0.76192, Test ACC: 0.64331, Test F1: 0.65000, TEST SPE: 0.65333, TEST SEN: 0.63415, TEST AUC: 0.65902
# CV: 003, Epoch: 047, Val Loss: 24.66157, Val ACC: 0.69014,Val AUC: 0.75020, Test ACC: 0.68153, Test F1: 0.70930, TEST SPE: 0.61333, TEST SEN: 0.74390, TEST AUC: 0.73805
# CV: 003, Epoch: 048, Val Loss: 31.14024, Val ACC: 0.67606,Val AUC: 0.74781, Test ACC: 0.56688, Test F1: 0.45161, TEST SPE: 0.81333, TEST SEN: 0.34146, TEST AUC: 0.70098
# CV: 003, Epoch: 049, Val Loss: 40.07291, Val ACC: 0.65493,Val AUC: 0.72615, Test ACC: 0.63057, Test F1: 0.71000, TEST SPE: 0.37333, TEST SEN: 0.86585, TEST AUC: 0.72130
# CV: 003, Epoch: 050, Val Loss: 38.50626, Val ACC: 0.65493,Val AUC: 0.69197, Test ACC: 0.66879, Test F1: 0.64384, TEST SPE: 0.77333, TEST SEN: 0.57317, TEST AUC: 0.76472
# CV: 004, Epoch: 001, Val Loss: 17.30141, Val ACC: 0.66197,Val AUC: 0.73907, Test ACC: 0.64331, Test F1: 0.58209, TEST SPE: 0.82667, TEST SEN: 0.47561, TEST AUC: 0.74732
# CV: 004, Epoch: 002, Val Loss: 17.03658, Val ACC: 0.68310,Val AUC: 0.74881, Test ACC: 0.65605, Test F1: 0.61972, TEST SPE: 0.78667, TEST SEN: 0.53659, TEST AUC: 0.76813
# CV: 004, Epoch: 003, Val Loss: 19.89887, Val ACC: 0.64789,Val AUC: 0.68979, Test ACC: 0.62420, Test F1: 0.70352, TEST SPE: 0.37333, TEST SEN: 0.85366, TEST AUC: 0.71854
# CV: 004, Epoch: 004, Val Loss: 18.88624, Val ACC: 0.61268,Val AUC: 0.69893, Test ACC: 0.65605, Test F1: 0.55000, TEST SPE: 0.93333, TEST SEN: 0.40244, TEST AUC: 0.78797
# CV: 004, Epoch: 005, Val Loss: 19.86115, Val ACC: 0.59859,Val AUC: 0.68839, Test ACC: 0.66879, Test F1: 0.64384, TEST SPE: 0.77333, TEST SEN: 0.57317, TEST AUC: 0.75496
# CV: 004, Epoch: 006, Val Loss: 21.75574, Val ACC: 0.64085,Val AUC: 0.69634, Test ACC: 0.65605, Test F1: 0.74286, TEST SPE: 0.33333, TEST SEN: 0.95122, TEST AUC: 0.77073
# CV: 004, Epoch: 007, Val Loss: 47.43456, Val ACC: 0.59859,Val AUC: 0.57552, Test ACC: 0.61146, Test F1: 0.71362, TEST SPE: 0.26667, TEST SEN: 0.92683, TEST AUC: 0.61740
# CV: 004, Epoch: 008, Val Loss: 27.41730, Val ACC: 0.60563,Val AUC: 0.65362, Test ACC: 0.63057, Test F1: 0.60811, TEST SPE: 0.72000, TEST SEN: 0.54878, TEST AUC: 0.70634
# CV: 004, Epoch: 009, Val Loss: 19.32879, Val ACC: 0.61268,Val AUC: 0.68979, Test ACC: 0.71338, Test F1: 0.73054, TEST SPE: 0.68000, TEST SEN: 0.74390, TEST AUC: 0.77024
# CV: 004, Epoch: 010, Val Loss: 41.60474, Val ACC: 0.57746,Val AUC: 0.76709, Test ACC: 0.60510, Test F1: 0.41509, TEST SPE: 0.97333, TEST SEN: 0.26829, TEST AUC: 0.76293
# CV: 004, Epoch: 011, Val Loss: 29.21392, Val ACC: 0.59859,Val AUC: 0.65779, Test ACC: 0.64968, Test F1: 0.60432, TEST SPE: 0.80000, TEST SEN: 0.51220, TEST AUC: 0.72618
# CV: 004, Epoch: 012, Val Loss: 31.14996, Val ACC: 0.59155,Val AUC: 0.64964, Test ACC: 0.57962, Test F1: 0.69725, TEST SPE: 0.20000, TEST SEN: 0.92683, TEST AUC: 0.66846
# CV: 004, Epoch: 013, Val Loss: 36.12646, Val ACC: 0.57746,Val AUC: 0.60612, Test ACC: 0.61146, Test F1: 0.69951, TEST SPE: 0.33333, TEST SEN: 0.86585, TEST AUC: 0.66634
# CV: 004, Epoch: 014, Val Loss: 60.45931, Val ACC: 0.54930,Val AUC: 0.70608, Test ACC: 0.54140, Test F1: 0.68966, TEST SPE: 0.06667, TEST SEN: 0.97561, TEST AUC: 0.69171
# CV: 004, Epoch: 015, Val Loss: 52.74021, Val ACC: 0.58451,Val AUC: 0.70986, Test ACC: 0.56688, Test F1: 0.30612, TEST SPE: 0.98667, TEST SEN: 0.18293, TEST AUC: 0.76959
# CV: 004, Epoch: 016, Val Loss: 30.25423, Val ACC: 0.64085,Val AUC: 0.76669, Test ACC: 0.60510, Test F1: 0.71028, TEST SPE: 0.25333, TEST SEN: 0.92683, TEST AUC: 0.75333
# CV: 004, Epoch: 017, Val Loss: 39.38697, Val ACC: 0.56338,Val AUC: 0.58943, Test ACC: 0.57325, Test F1: 0.58896, TEST SPE: 0.56000, TEST SEN: 0.58537, TEST AUC: 0.62992
# CV: 004, Epoch: 018, Val Loss: 33.58639, Val ACC: 0.54225,Val AUC: 0.58744, Test ACC: 0.65605, Test F1: 0.71875, TEST SPE: 0.45333, TEST SEN: 0.84146, TEST AUC: 0.65691
# CV: 004, Epoch: 019, Val Loss: 21.98395, Val ACC: 0.69014,Val AUC: 0.74026, Test ACC: 0.71975, Test F1: 0.74419, TEST SPE: 0.65333, TEST SEN: 0.78049, TEST AUC: 0.75837
# CV: 004, Epoch: 020, Val Loss: 40.72486, Val ACC: 0.57042,Val AUC: 0.57134, Test ACC: 0.62420, Test F1: 0.65896, TEST SPE: 0.54667, TEST SEN: 0.69512, TEST AUC: 0.61789
# CV: 004, Epoch: 021, Val Loss: 46.13561, Val ACC: 0.63380,Val AUC: 0.73430, Test ACC: 0.59873, Test F1: 0.69856, TEST SPE: 0.28000, TEST SEN: 0.89024, TEST AUC: 0.71187
# CV: 004, Epoch: 022, Val Loss: 21.59271, Val ACC: 0.69014,Val AUC: 0.77444, Test ACC: 0.73248, Test F1: 0.74390, TEST SPE: 0.72000, TEST SEN: 0.74390, TEST AUC: 0.78211
# CV: 004, Epoch: 023, Val Loss: 44.75748, Val ACC: 0.61268,Val AUC: 0.74066, Test ACC: 0.59236, Test F1: 0.70093, TEST SPE: 0.24000, TEST SEN: 0.91463, TEST AUC: 0.71837
# CV: 004, Epoch: 024, Val Loss: 26.72140, Val ACC: 0.61972,Val AUC: 0.72059, Test ACC: 0.71338, Test F1: 0.73373, TEST SPE: 0.66667, TEST SEN: 0.75610, TEST AUC: 0.78407
# CV: 004, Epoch: 025, Val Loss: 22.89094, Val ACC: 0.73239,Val AUC: 0.76312, Test ACC: 0.64331, Test F1: 0.70213, TEST SPE: 0.46667, TEST SEN: 0.80488, TEST AUC: 0.74455
# CV: 004, Epoch: 026, Val Loss: 52.62825, Val ACC: 0.61268,Val AUC: 0.75139, Test ACC: 0.62420, Test F1: 0.47788, TEST SPE: 0.94667, TEST SEN: 0.32927, TEST AUC: 0.76585
# CV: 004, Epoch: 027, Val Loss: 60.31685, Val ACC: 0.52113,Val AUC: 0.61963, Test ACC: 0.53503, Test F1: 0.68670, TEST SPE: 0.05333, TEST SEN: 0.97561, TEST AUC: 0.67821
# CV: 004, Epoch: 028, Val Loss: 28.49888, Val ACC: 0.64085,Val AUC: 0.70111, Test ACC: 0.61783, Test F1: 0.68750, TEST SPE: 0.41333, TEST SEN: 0.80488, TEST AUC: 0.74341
# CV: 004, Epoch: 029, Val Loss: 41.05944, Val ACC: 0.59859,Val AUC: 0.62659, Test ACC: 0.56051, Test F1: 0.54902, TEST SPE: 0.61333, TEST SEN: 0.51220, TEST AUC: 0.65642
# CV: 004, Epoch: 030, Val Loss: 48.32786, Val ACC: 0.57042,Val AUC: 0.69555, Test ACC: 0.64331, Test F1: 0.53333, TEST SPE: 0.92000, TEST SEN: 0.39024, TEST AUC: 0.72244
# CV: 004, Epoch: 031, Val Loss: 68.40112, Val ACC: 0.54930,Val AUC: 0.57055, Test ACC: 0.60510, Test F1: 0.64773, TEST SPE: 0.50667, TEST SEN: 0.69512, TEST AUC: 0.59821
# CV: 004, Epoch: 032, Val Loss: 105.85580, Val ACC: 0.52113,Val AUC: 0.71075, Test ACC: 0.52229, Test F1: 0.68619, TEST SPE: 0.00000, TEST SEN: 1.00000, TEST AUC: 0.71959
# CV: 004, Epoch: 033, Val Loss: 49.18794, Val ACC: 0.60563,Val AUC: 0.68581, Test ACC: 0.59236, Test F1: 0.70370, TEST SPE: 0.22667, TEST SEN: 0.92683, TEST AUC: 0.72520
# CV: 004, Epoch: 034, Val Loss: 45.24524, Val ACC: 0.60563,Val AUC: 0.65620, Test ACC: 0.61146, Test F1: 0.53435, TEST SPE: 0.81333, TEST SEN: 0.42683, TEST AUC: 0.70114
# CV: 004, Epoch: 035, Val Loss: 38.35125, Val ACC: 0.67606,Val AUC: 0.72715, Test ACC: 0.66879, Test F1: 0.69412, TEST SPE: 0.61333, TEST SEN: 0.71951, TEST AUC: 0.70488
# CV: 004, Epoch: 036, Val Loss: 62.14517, Val ACC: 0.61972,Val AUC: 0.68223, Test ACC: 0.57962, Test F1: 0.66327, TEST SPE: 0.34667, TEST SEN: 0.79268, TEST AUC: 0.71341
# CV: 004, Epoch: 037, Val Loss: 28.02143, Val ACC: 0.69014,Val AUC: 0.78657, Test ACC: 0.68790, Test F1: 0.65734, TEST SPE: 0.81333, TEST SEN: 0.57317, TEST AUC: 0.74569
# CV: 004, Epoch: 038, Val Loss: 74.08186, Val ACC: 0.54225,Val AUC: 0.58784, Test ACC: 0.57962, Test F1: 0.59259, TEST SPE: 0.57333, TEST SEN: 0.58537, TEST AUC: 0.61447
# CV: 004, Epoch: 039, Val Loss: 43.35566, Val ACC: 0.60563,Val AUC: 0.76789, Test ACC: 0.57962, Test F1: 0.70270, TEST SPE: 0.17333, TEST SEN: 0.95122, TEST AUC: 0.74423
# CV: 004, Epoch: 040, Val Loss: 61.93221, Val ACC: 0.59155,Val AUC: 0.59112, Test ACC: 0.63694, Test F1: 0.70769, TEST SPE: 0.41333, TEST SEN: 0.84146, TEST AUC: 0.61870
# CV: 004, Epoch: 041, Val Loss: 35.37932, Val ACC: 0.64085,Val AUC: 0.68442, Test ACC: 0.63057, Test F1: 0.61333, TEST SPE: 0.70667, TEST SEN: 0.56098, TEST AUC: 0.72358
# CV: 004, Epoch: 042, Val Loss: 44.26894, Val ACC: 0.67606,Val AUC: 0.76928, Test ACC: 0.62420, Test F1: 0.70647, TEST SPE: 0.36000, TEST SEN: 0.86585, TEST AUC: 0.74374
# CV: 004, Epoch: 043, Val Loss: 87.77419, Val ACC: 0.49296,Val AUC: 0.67806, Test ACC: 0.55414, Test F1: 0.25532, TEST SPE: 1.00000, TEST SEN: 0.14634, TEST AUC: 0.71122
# CV: 004, Epoch: 044, Val Loss: 63.66229, Val ACC: 0.55634,Val AUC: 0.64308, Test ACC: 0.56688, Test F1: 0.70175, TEST SPE: 0.12000, TEST SEN: 0.97561, TEST AUC: 0.68041
# CV: 004, Epoch: 045, Val Loss: 60.49062, Val ACC: 0.57042,Val AUC: 0.62579, Test ACC: 0.59236, Test F1: 0.56757, TEST SPE: 0.68000, TEST SEN: 0.51220, TEST AUC: 0.65138
# CV: 004, Epoch: 046, Val Loss: 67.95548, Val ACC: 0.52113,Val AUC: 0.60572, Test ACC: 0.52866, Test F1: 0.37288, TEST SPE: 0.81333, TEST SEN: 0.26829, TEST AUC: 0.63041
# CV: 004, Epoch: 047, Val Loss: 36.81893, Val ACC: 0.59859,Val AUC: 0.66057, Test ACC: 0.68790, Test F1: 0.66667, TEST SPE: 0.78667, TEST SEN: 0.59756, TEST AUC: 0.73203
# CV: 004, Epoch: 048, Val Loss: 27.99670, Val ACC: 0.73239,Val AUC: 0.76510, Test ACC: 0.64331, Test F1: 0.68889, TEST SPE: 0.52000, TEST SEN: 0.75610, TEST AUC: 0.74407
# CV: 004, Epoch: 049, Val Loss: 52.26530, Val ACC: 0.59155,Val AUC: 0.70529, Test ACC: 0.63694, Test F1: 0.53659, TEST SPE: 0.89333, TEST SEN: 0.40244, TEST AUC: 0.70358
# CV: 004, Epoch: 050, Val Loss: 29.05708, Val ACC: 0.66901,Val AUC: 0.74126, Test ACC: 0.62420, Test F1: 0.66286, TEST SPE: 0.53333, TEST SEN: 0.70732, TEST AUC: 0.72374
# CV: 005, Epoch: 001, Val Loss: 18.41003, Val ACC: 0.66197,Val AUC: 0.69793, Test ACC: 0.63057, Test F1: 0.70408, TEST SPE: 0.39474, TEST SEN: 0.85185, TEST AUC: 0.71784
# CV: 005, Epoch: 002, Val Loss: 18.00276, Val ACC: 0.65493,Val AUC: 0.70429, Test ACC: 0.60510, Test F1: 0.65169, TEST SPE: 0.48684, TEST SEN: 0.71605, TEST AUC: 0.70906
# CV: 005, Epoch: 003, Val Loss: 17.78980, Val ACC: 0.64085,Val AUC: 0.70986, Test ACC: 0.62420, Test F1: 0.66667, TEST SPE: 0.51316, TEST SEN: 0.72840, TEST AUC: 0.70809
# CV: 005, Epoch: 004, Val Loss: 28.02941, Val ACC: 0.52113,Val AUC: 0.60791, Test ACC: 0.56051, Test F1: 0.37838, TEST SPE: 0.88158, TEST SEN: 0.25926, TEST AUC: 0.59714
# CV: 005, Epoch: 005, Val Loss: 24.35428, Val ACC: 0.64085,Val AUC: 0.66952, Test ACC: 0.59873, Test F1: 0.70423, TEST SPE: 0.25000, TEST SEN: 0.92593, TEST AUC: 0.69103
# CV: 005, Epoch: 006, Val Loss: 18.58046, Val ACC: 0.67606,Val AUC: 0.70966, Test ACC: 0.67516, Test F1: 0.72432, TEST SPE: 0.51316, TEST SEN: 0.82716, TEST AUC: 0.71914
# CV: 005, Epoch: 007, Val Loss: 37.46570, Val ACC: 0.50000,Val AUC: 0.67945, Test ACC: 0.56051, Test F1: 0.30303, TEST SPE: 0.96053, TEST SEN: 0.18519, TEST AUC: 0.67154
# CV: 005, Epoch: 008, Val Loss: 29.24917, Val ACC: 0.66197,Val AUC: 0.67905, Test ACC: 0.61146, Test F1: 0.70244, TEST SPE: 0.31579, TEST SEN: 0.88889, TEST AUC: 0.68795
# CV: 005, Epoch: 009, Val Loss: 28.80735, Val ACC: 0.58451,Val AUC: 0.64587, Test ACC: 0.62420, Test F1: 0.63804, TEST SPE: 0.60526, TEST SEN: 0.64198, TEST AUC: 0.69266
# CV: 005, Epoch: 010, Val Loss: 22.15426, Val ACC: 0.66901,Val AUC: 0.70767, Test ACC: 0.66879, Test F1: 0.72917, TEST SPE: 0.46053, TEST SEN: 0.86420, TEST AUC: 0.73246
# CV: 005, Epoch: 011, Val Loss: 34.28222, Val ACC: 0.63380,Val AUC: 0.64964, Test ACC: 0.62420, Test F1: 0.66286, TEST SPE: 0.52632, TEST SEN: 0.71605, TEST AUC: 0.66732
# CV: 005, Epoch: 012, Val Loss: 22.72328, Val ACC: 0.64789,Val AUC: 0.67905, Test ACC: 0.67516, Test F1: 0.72727, TEST SPE: 0.50000, TEST SEN: 0.83951, TEST AUC: 0.72888
# CV: 005, Epoch: 013, Val Loss: 27.03110, Val ACC: 0.55634,Val AUC: 0.72357, Test ACC: 0.66242, Test F1: 0.58268, TEST SPE: 0.88158, TEST SEN: 0.45679, TEST AUC: 0.74643
# CV: 005, Epoch: 014, Val Loss: 36.21549, Val ACC: 0.60563,Val AUC: 0.66753, Test ACC: 0.62420, Test F1: 0.59310, TEST SPE: 0.72368, TEST SEN: 0.53086, TEST AUC: 0.70110
# CV: 005, Epoch: 015, Val Loss: 21.19515, Val ACC: 0.67606,Val AUC: 0.70072, Test ACC: 0.66242, Test F1: 0.71038, TEST SPE: 0.51316, TEST SEN: 0.80247, TEST AUC: 0.76478
# CV: 005, Epoch: 016, Val Loss: 35.56237, Val ACC: 0.54930,Val AUC: 0.63414, Test ACC: 0.60510, Test F1: 0.47458, TEST SPE: 0.88158, TEST SEN: 0.34568, TEST AUC: 0.66569
# CV: 005, Epoch: 017, Val Loss: 25.29153, Val ACC: 0.58451,Val AUC: 0.65183, Test ACC: 0.61146, Test F1: 0.58503, TEST SPE: 0.69737, TEST SEN: 0.53086, TEST AUC: 0.65318
# CV: 005, Epoch: 018, Val Loss: 27.03593, Val ACC: 0.60563,Val AUC: 0.63116, Test ACC: 0.60510, Test F1: 0.66667, TEST SPE: 0.43421, TEST SEN: 0.76543, TEST AUC: 0.65984
# CV: 005, Epoch: 019, Val Loss: 45.64358, Val ACC: 0.64085,Val AUC: 0.65362, Test ACC: 0.65605, Test F1: 0.71875, TEST SPE: 0.44737, TEST SEN: 0.85185, TEST AUC: 0.69786
# CV: 005, Epoch: 020, Val Loss: 56.02713, Val ACC: 0.59155,Val AUC: 0.63037, Test ACC: 0.59236, Test F1: 0.68317, TEST SPE: 0.31579, TEST SEN: 0.85185, TEST AUC: 0.64799
# CV: 005, Epoch: 021, Val Loss: 29.05610, Val ACC: 0.61268,Val AUC: 0.69614, Test ACC: 0.63057, Test F1: 0.62821, TEST SPE: 0.65789, TEST SEN: 0.60494, TEST AUC: 0.73652
# CV: 005, Epoch: 022, Val Loss: 78.38727, Val ACC: 0.47887,Val AUC: 0.71681, Test ACC: 0.50955, Test F1: 0.09412, TEST SPE: 1.00000, TEST SEN: 0.04938, TEST AUC: 0.72661
# CV: 005, Epoch: 023, Val Loss: 27.30588, Val ACC: 0.60563,Val AUC: 0.68641, Test ACC: 0.61783, Test F1: 0.53846, TEST SPE: 0.81579, TEST SEN: 0.43210, TEST AUC: 0.70809
# CV: 005, Epoch: 024, Val Loss: 45.58085, Val ACC: 0.57042,Val AUC: 0.62599, Test ACC: 0.61783, Test F1: 0.50000, TEST SPE: 0.88158, TEST SEN: 0.37037, TEST AUC: 0.62947
# CV: 005, Epoch: 025, Val Loss: 38.00148, Val ACC: 0.58451,Val AUC: 0.66773, Test ACC: 0.63694, Test F1: 0.58993, TEST SPE: 0.77632, TEST SEN: 0.50617, TEST AUC: 0.66147
# CV: 005, Epoch: 026, Val Loss: 39.44591, Val ACC: 0.57746,Val AUC: 0.60294, Test ACC: 0.54777, Test F1: 0.58480, TEST SPE: 0.47368, TEST SEN: 0.61728, TEST AUC: 0.61696
# CV: 005, Epoch: 027, Val Loss: 30.89314, Val ACC: 0.59155,Val AUC: 0.73013, Test ACC: 0.62420, Test F1: 0.52800, TEST SPE: 0.85526, TEST SEN: 0.40741, TEST AUC: 0.71491
# CV: 005, Epoch: 028, Val Loss: 73.94553, Val ACC: 0.60563,Val AUC: 0.65809, Test ACC: 0.63057, Test F1: 0.65060, TEST SPE: 0.59211, TEST SEN: 0.66667, TEST AUC: 0.67065
# CV: 005, Epoch: 029, Val Loss: 31.41891, Val ACC: 0.59859,Val AUC: 0.70866, Test ACC: 0.67516, Test F1: 0.65306, TEST SPE: 0.76316, TEST SEN: 0.59259, TEST AUC: 0.75276
# CV: 005, Epoch: 030, Val Loss: 35.77603, Val ACC: 0.62676,Val AUC: 0.66693, Test ACC: 0.64331, Test F1: 0.61111, TEST SPE: 0.75000, TEST SEN: 0.54321, TEST AUC: 0.66391
# CV: 005, Epoch: 031, Val Loss: 29.39770, Val ACC: 0.64085,Val AUC: 0.70946, Test ACC: 0.61783, Test F1: 0.70000, TEST SPE: 0.35526, TEST SEN: 0.86420, TEST AUC: 0.72612
# CV: 005, Epoch: 032, Val Loss: 29.20815, Val ACC: 0.66901,Val AUC: 0.71145, Test ACC: 0.68790, Test F1: 0.70303, TEST SPE: 0.65789, TEST SEN: 0.71605, TEST AUC: 0.76348
# CV: 005, Epoch: 033, Val Loss: 52.84733, Val ACC: 0.51408,Val AUC: 0.72536, Test ACC: 0.61783, Test F1: 0.44444, TEST SPE: 0.96053, TEST SEN: 0.29630, TEST AUC: 0.74220
# CV: 005, Epoch: 034, Val Loss: 47.65907, Val ACC: 0.57746,Val AUC: 0.58684, Test ACC: 0.57962, Test F1: 0.53521, TEST SPE: 0.69737, TEST SEN: 0.46914, TEST AUC: 0.63272
# CV: 005, Epoch: 035, Val Loss: 54.45152, Val ACC: 0.61972,Val AUC: 0.65342, Test ACC: 0.65605, Test F1: 0.69318, TEST SPE: 0.55263, TEST SEN: 0.75309, TEST AUC: 0.68307
# CV: 005, Epoch: 036, Val Loss: 33.30320, Val ACC: 0.59155,Val AUC: 0.68243, Test ACC: 0.61146, Test F1: 0.52713, TEST SPE: 0.81579, TEST SEN: 0.41975, TEST AUC: 0.70062
# CV: 005, Epoch: 037, Val Loss: 72.53023, Val ACC: 0.49296,Val AUC: 0.72893, Test ACC: 0.55414, Test F1: 0.23913, TEST SPE: 1.00000, TEST SEN: 0.13580, TEST AUC: 0.77209
# CV: 005, Epoch: 038, Val Loss: 35.17621, Val ACC: 0.56338,Val AUC: 0.69297, Test ACC: 0.63694, Test F1: 0.54400, TEST SPE: 0.86842, TEST SEN: 0.41975, TEST AUC: 0.70695
# CV: 005, Epoch: 039, Val Loss: 37.79597, Val ACC: 0.62676,Val AUC: 0.69595, Test ACC: 0.65605, Test F1: 0.60294, TEST SPE: 0.81579, TEST SEN: 0.50617, TEST AUC: 0.73116
# CV: 005, Epoch: 040, Val Loss: 69.83679, Val ACC: 0.54930,Val AUC: 0.68392, Test ACC: 0.57962, Test F1: 0.70536, TEST SPE: 0.15789, TEST SEN: 0.97531, TEST AUC: 0.73554
# CV: 005, Epoch: 041, Val Loss: 49.40545, Val ACC: 0.58451,Val AUC: 0.69773, Test ACC: 0.63057, Test F1: 0.57971, TEST SPE: 0.77632, TEST SEN: 0.49383, TEST AUC: 0.72044
# CV: 005, Epoch: 042, Val Loss: 35.18229, Val ACC: 0.63380,Val AUC: 0.70986, Test ACC: 0.68153, Test F1: 0.70930, TEST SPE: 0.60526, TEST SEN: 0.75309, TEST AUC: 0.75081
# CV: 005, Epoch: 043, Val Loss: 59.70626, Val ACC: 0.66901,Val AUC: 0.64944, Test ACC: 0.65605, Test F1: 0.72449, TEST SPE: 0.42105, TEST SEN: 0.87654, TEST AUC: 0.68908
# CV: 005, Epoch: 044, Val Loss: 63.68217, Val ACC: 0.52113,Val AUC: 0.63494, Test ACC: 0.58599, Test F1: 0.38095, TEST SPE: 0.94737, TEST SEN: 0.24691, TEST AUC: 0.69558
# CV: 005, Epoch: 045, Val Loss: 126.63349, Val ACC: 0.46479,Val AUC: 0.59917, Test ACC: 0.51592, Test F1: 0.11628, TEST SPE: 1.00000, TEST SEN: 0.06173, TEST AUC: 0.58041
# CV: 005, Epoch: 046, Val Loss: 51.42930, Val ACC: 0.52817,Val AUC: 0.69813, Test ACC: 0.59873, Test F1: 0.42202, TEST SPE: 0.93421, TEST SEN: 0.28395, TEST AUC: 0.71654
# CV: 005, Epoch: 047, Val Loss: 30.19321, Val ACC: 0.67606,Val AUC: 0.72536, Test ACC: 0.61146, Test F1: 0.68394, TEST SPE: 0.39474, TEST SEN: 0.81481, TEST AUC: 0.70858
# CV: 005, Epoch: 048, Val Loss: 134.90685, Val ACC: 0.47183,Val AUC: 0.62341, Test ACC: 0.52229, Test F1: 0.13793, TEST SPE: 1.00000, TEST SEN: 0.07407, TEST AUC: 0.63012
# CV: 005, Epoch: 049, Val Loss: 30.87039, Val ACC: 0.66197,Val AUC: 0.72397, Test ACC: 0.66879, Test F1: 0.67500, TEST SPE: 0.67105, TEST SEN: 0.66667, TEST AUC: 0.76949
# CV: 005, Epoch: 050, Val Loss: 69.22863, Val ACC: 0.59859,Val AUC: 0.65988, Test ACC: 0.63694, Test F1: 0.69189, TEST SPE: 0.47368, TEST SEN: 0.79012, TEST AUC: 0.69461
# CV: 006, Epoch: 001, Val Loss: 17.34605, Val ACC: 0.66197,Val AUC: 0.72576, Test ACC: 0.68153, Test F1: 0.71264, TEST SPE: 0.59211, TEST SEN: 0.76543, TEST AUC: 0.73798
# CV: 006, Epoch: 002, Val Loss: 17.53830, Val ACC: 0.69014,Val AUC: 0.71165, Test ACC: 0.66242, Test F1: 0.68263, TEST SPE: 0.61842, TEST SEN: 0.70370, TEST AUC: 0.74366
# CV: 006, Epoch: 003, Val Loss: 17.60180, Val ACC: 0.65493,Val AUC: 0.72536, Test ACC: 0.69427, Test F1: 0.72093, TEST SPE: 0.61842, TEST SEN: 0.76543, TEST AUC: 0.77031
# CV: 006, Epoch: 004, Val Loss: 17.58273, Val ACC: 0.65493,Val AUC: 0.73351, Test ACC: 0.68790, Test F1: 0.70303, TEST SPE: 0.65789, TEST SEN: 0.71605, TEST AUC: 0.75828
# CV: 006, Epoch: 005, Val Loss: 17.87478, Val ACC: 0.64085,Val AUC: 0.75735, Test ACC: 0.69427, Test F1: 0.66197, TEST SPE: 0.81579, TEST SEN: 0.58025, TEST AUC: 0.76170
# CV: 006, Epoch: 006, Val Loss: 27.68676, Val ACC: 0.53521,Val AUC: 0.75318, Test ACC: 0.56051, Test F1: 0.25806, TEST SPE: 1.00000, TEST SEN: 0.14815, TEST AUC: 0.77307
# CV: 006, Epoch: 007, Val Loss: 19.27728, Val ACC: 0.64085,Val AUC: 0.74126, Test ACC: 0.63057, Test F1: 0.53968, TEST SPE: 0.85526, TEST SEN: 0.41975, TEST AUC: 0.74675
# CV: 006, Epoch: 008, Val Loss: 23.18294, Val ACC: 0.61268,Val AUC: 0.71701, Test ACC: 0.62420, Test F1: 0.58156, TEST SPE: 0.75000, TEST SEN: 0.50617, TEST AUC: 0.68746
# CV: 006, Epoch: 009, Val Loss: 43.32110, Val ACC: 0.56338,Val AUC: 0.71264, Test ACC: 0.57325, Test F1: 0.70742, TEST SPE: 0.11842, TEST SEN: 1.00000, TEST AUC: 0.71800
# CV: 006, Epoch: 010, Val Loss: 21.95036, Val ACC: 0.66197,Val AUC: 0.74205, Test ACC: 0.71975, Test F1: 0.72152, TEST SPE: 0.73684, TEST SEN: 0.70370, TEST AUC: 0.78882
# CV: 006, Epoch: 011, Val Loss: 30.53192, Val ACC: 0.64789,Val AUC: 0.73013, Test ACC: 0.68790, Test F1: 0.61417, TEST SPE: 0.90789, TEST SEN: 0.48148, TEST AUC: 0.76332
# CV: 006, Epoch: 012, Val Loss: 31.71480, Val ACC: 0.61268,Val AUC: 0.67905, Test ACC: 0.66242, Test F1: 0.56911, TEST SPE: 0.90789, TEST SEN: 0.43210, TEST AUC: 0.70841
# CV: 006, Epoch: 013, Val Loss: 37.60471, Val ACC: 0.57746,Val AUC: 0.66037, Test ACC: 0.59236, Test F1: 0.70370, TEST SPE: 0.22368, TEST SEN: 0.93827, TEST AUC: 0.68616
# CV: 006, Epoch: 014, Val Loss: 41.61134, Val ACC: 0.62676,Val AUC: 0.66594, Test ACC: 0.65605, Test F1: 0.72449, TEST SPE: 0.42105, TEST SEN: 0.87654, TEST AUC: 0.69006
# CV: 006, Epoch: 015, Val Loss: 19.04474, Val ACC: 0.71127,Val AUC: 0.78458, Test ACC: 0.73248, Test F1: 0.72727, TEST SPE: 0.77632, TEST SEN: 0.69136, TEST AUC: 0.81644
# CV: 006, Epoch: 016, Val Loss: 28.84712, Val ACC: 0.62676,Val AUC: 0.72814, Test ACC: 0.65605, Test F1: 0.57143, TEST SPE: 0.88158, TEST SEN: 0.44444, TEST AUC: 0.76673
# CV: 006, Epoch: 017, Val Loss: 66.42524, Val ACC: 0.52817,Val AUC: 0.65938, Test ACC: 0.51592, Test F1: 0.67797, TEST SPE: 0.01316, TEST SEN: 0.98765, TEST AUC: 0.69639
# CV: 006, Epoch: 018, Val Loss: 24.75411, Val ACC: 0.64085,Val AUC: 0.70926, Test ACC: 0.64331, Test F1: 0.67816, TEST SPE: 0.55263, TEST SEN: 0.72840, TEST AUC: 0.73538
# CV: 006, Epoch: 019, Val Loss: 30.21398, Val ACC: 0.61972,Val AUC: 0.69674, Test ACC: 0.61783, Test F1: 0.64706, TEST SPE: 0.55263, TEST SEN: 0.67901, TEST AUC: 0.69818
# CV: 006, Epoch: 020, Val Loss: 29.14424, Val ACC: 0.66197,Val AUC: 0.70707, Test ACC: 0.67516, Test F1: 0.72727, TEST SPE: 0.50000, TEST SEN: 0.83951, TEST AUC: 0.72531
# CV: 006, Epoch: 021, Val Loss: 26.58851, Val ACC: 0.65493,Val AUC: 0.71880, Test ACC: 0.66242, Test F1: 0.71958, TEST SPE: 0.47368, TEST SEN: 0.83951, TEST AUC: 0.74724
# CV: 006, Epoch: 022, Val Loss: 39.75740, Val ACC: 0.64789,Val AUC: 0.73887, Test ACC: 0.62420, Test F1: 0.52033, TEST SPE: 0.86842, TEST SEN: 0.39506, TEST AUC: 0.77762
# CV: 006, Epoch: 023, Val Loss: 19.24028, Val ACC: 0.71831,Val AUC: 0.79173, Test ACC: 0.68153, Test F1: 0.66667, TEST SPE: 0.75000, TEST SEN: 0.61728, TEST AUC: 0.80344
# CV: 006, Epoch: 024, Val Loss: 27.30551, Val ACC: 0.66197,Val AUC: 0.77246, Test ACC: 0.64968, Test F1: 0.55285, TEST SPE: 0.89474, TEST SEN: 0.41975, TEST AUC: 0.77794
# CV: 006, Epoch: 025, Val Loss: 50.46926, Val ACC: 0.54930,Val AUC: 0.62162, Test ACC: 0.56051, Test F1: 0.59172, TEST SPE: 0.50000, TEST SEN: 0.61728, TEST AUC: 0.60266
# CV: 006, Epoch: 026, Val Loss: 41.65993, Val ACC: 0.59859,Val AUC: 0.71244, Test ACC: 0.56688, Test F1: 0.40351, TEST SPE: 0.86842, TEST SEN: 0.28395, TEST AUC: 0.70582
# CV: 006, Epoch: 027, Val Loss: 27.76856, Val ACC: 0.61972,Val AUC: 0.71025, Test ACC: 0.66242, Test F1: 0.67081, TEST SPE: 0.65789, TEST SEN: 0.66667, TEST AUC: 0.74513
# CV: 006, Epoch: 028, Val Loss: 33.45197, Val ACC: 0.61972,Val AUC: 0.68303, Test ACC: 0.60510, Test F1: 0.50794, TEST SPE: 0.82895, TEST SEN: 0.39506, TEST AUC: 0.70955
# CV: 006, Epoch: 029, Val Loss: 38.65021, Val ACC: 0.61972,Val AUC: 0.68243, Test ACC: 0.68790, Test F1: 0.75127, TEST SPE: 0.44737, TEST SEN: 0.91358, TEST AUC: 0.69217
# CV: 006, Epoch: 030, Val Loss: 39.34273, Val ACC: 0.64789,Val AUC: 0.68959, Test ACC: 0.64331, Test F1: 0.72277, TEST SPE: 0.36842, TEST SEN: 0.90123, TEST AUC: 0.72222
# CV: 006, Epoch: 031, Val Loss: 26.17238, Val ACC: 0.67606,Val AUC: 0.73649, Test ACC: 0.66242, Test F1: 0.67485, TEST SPE: 0.64474, TEST SEN: 0.67901, TEST AUC: 0.75114
# CV: 006, Epoch: 032, Val Loss: 37.94292, Val ACC: 0.64085,Val AUC: 0.67627, Test ACC: 0.66242, Test F1: 0.65359, TEST SPE: 0.71053, TEST SEN: 0.61728, TEST AUC: 0.71118
# CV: 006, Epoch: 033, Val Loss: 23.71461, Val ACC: 0.72535,Val AUC: 0.77802, Test ACC: 0.70064, Test F1: 0.74866, TEST SPE: 0.52632, TEST SEN: 0.86420, TEST AUC: 0.79418
# CV: 006, Epoch: 034, Val Loss: 38.17344, Val ACC: 0.60563,Val AUC: 0.75636, Test ACC: 0.60510, Test F1: 0.71818, TEST SPE: 0.21053, TEST SEN: 0.97531, TEST AUC: 0.76819
# ...
# CV: 009, Epoch: 007, Val Loss: 18.55426, Val ACC: 0.64789,Val AUC: 0.77961, Test ACC: 0.66242, Test F1: 0.59542, TEST SPE: 0.85526, TEST SEN: 0.48148, TEST AUC: 0.75975
# CV: 009, Epoch: 008, Val Loss: 21.21496, Val ACC: 0.64085,Val AUC: 0.73450, Test ACC: 0.62420, Test F1: 0.71220, TEST SPE: 0.32895, TEST SEN: 0.90123, TEST AUC: 0.68876
# CV: 009, Epoch: 009, Val Loss: 23.71133, Val ACC: 0.57042,Val AUC: 0.76252, Test ACC: 0.56051, Test F1: 0.70130, TEST SPE: 0.09211, TEST SEN: 1.00000, TEST AUC: 0.75227
# CV: 009, Epoch: 010, Val Loss: 16.19858, Val ACC: 0.73944,Val AUC: 0.77961, Test ACC: 0.69427, Test F1: 0.70732, TEST SPE: 0.67105, TEST SEN: 0.71605, TEST AUC: 0.75292
# CV: 009, Epoch: 011, Val Loss: 16.28824, Val ACC: 0.65493,Val AUC: 0.77126, Test ACC: 0.65605, Test F1: 0.68235, TEST SPE: 0.59211, TEST SEN: 0.71605, TEST AUC: 0.77177
# CV: 009, Epoch: 012, Val Loss: 18.65225, Val ACC: 0.66197,Val AUC: 0.80306, Test ACC: 0.67516, Test F1: 0.57143, TEST SPE: 0.94737, TEST SEN: 0.41975, TEST AUC: 0.82131
# CV: 009, Epoch: 013, Val Loss: 23.88412, Val ACC: 0.64789,Val AUC: 0.74483, Test ACC: 0.57962, Test F1: 0.40000, TEST SPE: 0.90789, TEST SEN: 0.27160, TEST AUC: 0.73603
# CV: 009, Epoch: 014, Val Loss: 32.67210, Val ACC: 0.58451,Val AUC: 0.76471, Test ACC: 0.57325, Test F1: 0.32323, TEST SPE: 0.97368, TEST SEN: 0.19753, TEST AUC: 0.71816
# CV: 009, Epoch: 015, Val Loss: 41.14381, Val ACC: 0.57042,Val AUC: 0.62202, Test ACC: 0.58599, Test F1: 0.55782, TEST SPE: 0.67105, TEST SEN: 0.50617, TEST AUC: 0.63824
# CV: 009, Epoch: 016, Val Loss: 16.93794, Val ACC: 0.66901,Val AUC: 0.76133, Test ACC: 0.71975, Test F1: 0.71795, TEST SPE: 0.75000, TEST SEN: 0.69136, TEST AUC: 0.80669
# CV: 009, Epoch: 017, Val Loss: 58.39116, Val ACC: 0.57746,Val AUC: 0.61347, Test ACC: 0.57962, Test F1: 0.70536, TEST SPE: 0.15789, TEST SEN: 0.97531, TEST AUC: 0.64815
# CV: 009, Epoch: 018, Val Loss: 30.73194, Val ACC: 0.61268,Val AUC: 0.65660, Test ACC: 0.67516, Test F1: 0.72727, TEST SPE: 0.50000, TEST SEN: 0.83951, TEST AUC: 0.66845
# CV: 009, Epoch: 019, Val Loss: 20.58767, Val ACC: 0.64789,Val AUC: 0.74921, Test ACC: 0.65605, Test F1: 0.58462, TEST SPE: 0.85526, TEST SEN: 0.46914, TEST AUC: 0.75292
# CV: 009, Epoch: 020, Val Loss: 18.37166, Val ACC: 0.71831,Val AUC: 0.76948, Test ACC: 0.70064, Test F1: 0.66667, TEST SPE: 0.82895, TEST SEN: 0.58025, TEST AUC: 0.78525
# CV: 009, Epoch: 021, Val Loss: 28.27862, Val ACC: 0.61972,Val AUC: 0.69257, Test ACC: 0.57325, Test F1: 0.53147, TEST SPE: 0.68421, TEST SEN: 0.46914, TEST AUC: 0.67463
# CV: 009, Epoch: 022, Val Loss: 41.10615, Val ACC: 0.57746,Val AUC: 0.71264, Test ACC: 0.57962, Test F1: 0.70796, TEST SPE: 0.14474, TEST SEN: 0.98765, TEST AUC: 0.75049
# CV: 009, Epoch: 023, Val Loss: 71.87606, Val ACC: 0.48592,Val AUC: 0.72933, Test ACC: 0.49682, Test F1: 0.04819, TEST SPE: 1.00000, TEST SEN: 0.02469, TEST AUC: 0.72580
# CV: 009, Epoch: 024, Val Loss: 50.94482, Val ACC: 0.59859,Val AUC: 0.69157, Test ACC: 0.58599, Test F1: 0.36893, TEST SPE: 0.96053, TEST SEN: 0.23457, TEST AUC: 0.68405
# CV: 009, Epoch: 025, Val Loss: 18.74397, Val ACC: 0.64789,Val AUC: 0.76967, Test ACC: 0.73885, Test F1: 0.76023, TEST SPE: 0.67105, TEST SEN: 0.80247, TEST AUC: 0.81417
# CV: 009, Epoch: 026, Val Loss: 25.69789, Val ACC: 0.61972,Val AUC: 0.69376, Test ACC: 0.61146, Test F1: 0.56115, TEST SPE: 0.75000, TEST SEN: 0.48148, TEST AUC: 0.66196
# CV: 009, Epoch: 027, Val Loss: 51.06272, Val ACC: 0.56338,Val AUC: 0.65600, Test ACC: 0.61783, Test F1: 0.70297, TEST SPE: 0.34211, TEST SEN: 0.87654, TEST AUC: 0.68860
# CV: 009, Epoch: 028, Val Loss: 26.81810, Val ACC: 0.69014,Val AUC: 0.76530, Test ACC: 0.61146, Test F1: 0.42991, TEST SPE: 0.96053, TEST SEN: 0.28395, TEST AUC: 0.74025
# CV: 009, Epoch: 029, Val Loss: 39.28026, Val ACC: 0.58451,Val AUC: 0.78716, Test ACC: 0.55414, Test F1: 0.23913, TEST SPE: 1.00000, TEST SEN: 0.13580, TEST AUC: 0.78330
# CV: 009, Epoch: 030, Val Loss: 38.75333, Val ACC: 0.57042,Val AUC: 0.72377, Test ACC: 0.57962, Test F1: 0.69444, TEST SPE: 0.21053, TEST SEN: 0.92593, TEST AUC: 0.68762
# CV: 009, Epoch: 031, Val Loss: 22.86480, Val ACC: 0.59155,Val AUC: 0.69396, Test ACC: 0.67516, Test F1: 0.69822, TEST SPE: 0.61842, TEST SEN: 0.72840, TEST AUC: 0.76998
# CV: 009, Epoch: 032, Val Loss: 50.70537, Val ACC: 0.61972,Val AUC: 0.66256, Test ACC: 0.60510, Test F1: 0.71028, TEST SPE: 0.25000, TEST SEN: 0.93827, TEST AUC: 0.71654
# CV: 009, Epoch: 033, Val Loss: 65.71231, Val ACC: 0.54225,Val AUC: 0.60970, Test ACC: 0.60510, Test F1: 0.69608, TEST SPE: 0.31579, TEST SEN: 0.87654, TEST AUC: 0.68648
# CV: 009, Epoch: 034, Val Loss: 33.60707, Val ACC: 0.63380,Val AUC: 0.71761, Test ACC: 0.63057, Test F1: 0.71569, TEST SPE: 0.34211, TEST SEN: 0.90123, TEST AUC: 0.77225
# CV: 009, Epoch: 035, Val Loss: 47.97091, Val ACC: 0.57746,Val AUC: 0.64030, Test ACC: 0.61783, Test F1: 0.66292, TEST SPE: 0.50000, TEST SEN: 0.72840, TEST AUC: 0.66545
# CV: 009, Epoch: 036, Val Loss: 71.16747, Val ACC: 0.56338,Val AUC: 0.64199, Test ACC: 0.56688, Test F1: 0.70175, TEST SPE: 0.11842, TEST SEN: 0.98765, TEST AUC: 0.71069
# CV: 009, Epoch: 037, Val Loss: 22.10092, Val ACC: 0.66901,Val AUC: 0.72794, Test ACC: 0.59873, Test F1: 0.58278, TEST SPE: 0.65789, TEST SEN: 0.54321, TEST AUC: 0.71670
# CV: 009, Epoch: 038, Val Loss: 46.66024, Val ACC: 0.58451,Val AUC: 0.70449, Test ACC: 0.60510, Test F1: 0.71560, TEST SPE: 0.22368, TEST SEN: 0.96296, TEST AUC: 0.74334
# CV: 009, Epoch: 039, Val Loss: 54.11443, Val ACC: 0.54225,Val AUC: 0.64507, Test ACC: 0.57962, Test F1: 0.68571, TEST SPE: 0.25000, TEST SEN: 0.88889, TEST AUC: 0.70517
# CV: 009, Epoch: 040, Val Loss: 33.51059, Val ACC: 0.64085,Val AUC: 0.71880, Test ACC: 0.64968, Test F1: 0.52991, TEST SPE: 0.93421, TEST SEN: 0.38272, TEST AUC: 0.78476
# CV: 009, Epoch: 041, Val Loss: 40.26137, Val ACC: 0.63380,Val AUC: 0.75417, Test ACC: 0.65605, Test F1: 0.50909, TEST SPE: 0.98684, TEST SEN: 0.34568, TEST AUC: 0.81222
# CV: 009, Epoch: 042, Val Loss: 31.73233, Val ACC: 0.66197,Val AUC: 0.73887, Test ACC: 0.63057, Test F1: 0.54688, TEST SPE: 0.84211, TEST SEN: 0.43210, TEST AUC: 0.75422
# CV: 009, Epoch: 043, Val Loss: 28.37108, Val ACC: 0.61972,Val AUC: 0.68621, Test ACC: 0.64968, Test F1: 0.65839, TEST SPE: 0.64474, TEST SEN: 0.65432, TEST AUC: 0.70793
# CV: 009, Epoch: 044, Val Loss: 26.87100, Val ACC: 0.63380,Val AUC: 0.75517, Test ACC: 0.70064, Test F1: 0.75393, TEST SPE: 0.50000, TEST SEN: 0.88889, TEST AUC: 0.80686
# CV: 009, Epoch: 045, Val Loss: 29.14541, Val ACC: 0.61972,Val AUC: 0.74503, Test ACC: 0.68153, Test F1: 0.74490, TEST SPE: 0.44737, TEST SEN: 0.90123, TEST AUC: 0.79353
# CV: 009, Epoch: 046, Val Loss: 23.19646, Val ACC: 0.66901,Val AUC: 0.76749, Test ACC: 0.70701, Test F1: 0.74157, TEST SPE: 0.59211, TEST SEN: 0.81481, TEST AUC: 0.81238
# CV: 009, Epoch: 047, Val Loss: 27.26105, Val ACC: 0.63380,Val AUC: 0.74324, Test ACC: 0.68790, Test F1: 0.65248, TEST SPE: 0.81579, TEST SEN: 0.56790, TEST AUC: 0.78460
# CV: 009, Epoch: 048, Val Loss: 37.02472, Val ACC: 0.63380,Val AUC: 0.69376, Test ACC: 0.64331, Test F1: 0.62667, TEST SPE: 0.71053, TEST SEN: 0.58025, TEST AUC: 0.70793
# CV: 009, Epoch: 049, Val Loss: 72.52080, Val ACC: 0.53521,Val AUC: 0.72764, Test ACC: 0.51592, Test F1: 0.68067, TEST SPE: 0.00000, TEST SEN: 1.00000, TEST AUC: 0.75097
# CV: 009, Epoch: 050, Val Loss: 31.92801, Val ACC: 0.64789,Val AUC: 0.69535, Test ACC: 0.59873, Test F1: 0.65193, TEST SPE: 0.46053, TEST SEN: 0.72840, TEST AUC: 0.66293
# CV: 010, Epoch: 001, Val Loss: 17.02706, Val ACC: 0.70423,Val AUC: 0.74722, Test ACC: 0.63694, Test F1: 0.68852, TEST SPE: 0.48684, TEST SEN: 0.77778, TEST AUC: 0.70110
# CV: 010, Epoch: 002, Val Loss: 17.71407, Val ACC: 0.66197,Val AUC: 0.73192, Test ACC: 0.59873, Test F1: 0.57143, TEST SPE: 0.68421, TEST SEN: 0.51852, TEST AUC: 0.69379
# CV: 010, Epoch: 003, Val Loss: 18.39227, Val ACC: 0.62676,Val AUC: 0.69416, Test ACC: 0.64968, Test F1: 0.68927, TEST SPE: 0.53947, TEST SEN: 0.75309, TEST AUC: 0.72758
# CV: 010, Epoch: 004, Val Loss: 27.88581, Val ACC: 0.61972,Val AUC: 0.58784, Test ACC: 0.65605, Test F1: 0.71579, TEST SPE: 0.46053, TEST SEN: 0.83951, TEST AUC: 0.70419
# CV: 010, Epoch: 005, Val Loss: 27.26335, Val ACC: 0.51408,Val AUC: 0.75636, Test ACC: 0.52866, Test F1: 0.17778, TEST SPE: 0.98684, TEST SEN: 0.09877, TEST AUC: 0.73619
# CV: 010, Epoch: 006, Val Loss: 29.98002, Val ACC: 0.54930,Val AUC: 0.78657, Test ACC: 0.52866, Test F1: 0.17778, TEST SPE: 0.98684, TEST SEN: 0.09877, TEST AUC: 0.72157
# CV: 010, Epoch: 007, Val Loss: 17.12948, Val ACC: 0.66901,Val AUC: 0.76689, Test ACC: 0.68790, Test F1: 0.64748, TEST SPE: 0.82895, TEST SEN: 0.55556, TEST AUC: 0.76949
# CV: 010, Epoch: 008, Val Loss: 31.81944, Val ACC: 0.56338,Val AUC: 0.75735, Test ACC: 0.52229, Test F1: 0.68354, TEST SPE: 0.01316, TEST SEN: 1.00000, TEST AUC: 0.74903
# CV: 010, Epoch: 009, Val Loss: 65.27519, Val ACC: 0.52817,Val AUC: 0.63971, Test ACC: 0.51592, Test F1: 0.68067, TEST SPE: 0.00000, TEST SEN: 1.00000, TEST AUC: 0.74545
# CV: 010, Epoch: 010, Val Loss: 41.72811, Val ACC: 0.57746,Val AUC: 0.75636, Test ACC: 0.54140, Test F1: 0.23404, TEST SPE: 0.97368, TEST SEN: 0.13580, TEST AUC: 0.57001
# CV: 010, Epoch: 011, Val Loss: 29.58949, Val ACC: 0.59859,Val AUC: 0.74901, Test ACC: 0.58599, Test F1: 0.71111, TEST SPE: 0.15789, TEST SEN: 0.98765, TEST AUC: 0.75682
# CV: 010, Epoch: 012, Val Loss: 47.99296, Val ACC: 0.57042,Val AUC: 0.60294, Test ACC: 0.66879, Test F1: 0.71111, TEST SPE: 0.53947, TEST SEN: 0.79012, TEST AUC: 0.70712
# CV: 010, Epoch: 013, Val Loss: 25.88015, Val ACC: 0.55634,Val AUC: 0.64110, Test ACC: 0.63057, Test F1: 0.59722, TEST SPE: 0.73684, TEST SEN: 0.53086, TEST AUC: 0.70760
# CV: 010, Epoch: 014, Val Loss: 22.70855, Val ACC: 0.66197,Val AUC: 0.74026, Test ACC: 0.54777, Test F1: 0.48921, TEST SPE: 0.68421, TEST SEN: 0.41975, TEST AUC: 0.57083
# CV: 010, Epoch: 015, Val Loss: 87.71590, Val ACC: 0.52113,Val AUC: 0.66574, Test ACC: 0.51592, Test F1: 0.68067, TEST SPE: 0.00000, TEST SEN: 1.00000, TEST AUC: 0.69542
# CV: 010, Epoch: 016, Val Loss: 38.56908, Val ACC: 0.52113,Val AUC: 0.59360, Test ACC: 0.59236, Test F1: 0.40741, TEST SPE: 0.93421, TEST SEN: 0.27160, TEST AUC: 0.69753
# CV: 010, Epoch: 017, Val Loss: 24.99069, Val ACC: 0.67606,Val AUC: 0.78855, Test ACC: 0.52866, Test F1: 0.43077, TEST SPE: 0.72368, TEST SEN: 0.34568, TEST AUC: 0.66683
# CV: 010, Epoch: 018, Val Loss: 49.78671, Val ACC: 0.63380,Val AUC: 0.57393, Test ACC: 0.61146, Test F1: 0.69951, TEST SPE: 0.32895, TEST SEN: 0.87654, TEST AUC: 0.72287
# CV: 010, Epoch: 019, Val Loss: 48.88389, Val ACC: 0.51408,Val AUC: 0.55664, Test ACC: 0.62420, Test F1: 0.61935, TEST SPE: 0.65789, TEST SEN: 0.59259, TEST AUC: 0.68259
# CV: 010, Epoch: 020, Val Loss: 32.73613, Val ACC: 0.59155,Val AUC: 0.64785, Test ACC: 0.68790, Test F1: 0.66207, TEST SPE: 0.78947, TEST SEN: 0.59259, TEST AUC: 0.72645
# CV: 010, Epoch: 021, Val Loss: 32.22581, Val ACC: 0.59155,Val AUC: 0.70787, Test ACC: 0.58599, Test F1: 0.42478, TEST SPE: 0.89474, TEST SEN: 0.29630, TEST AUC: 0.71621
# CV: 010, Epoch: 022, Val Loss: 28.15211, Val ACC: 0.63380,Val AUC: 0.73231, Test ACC: 0.63694, Test F1: 0.72727, TEST SPE: 0.31579, TEST SEN: 0.93827, TEST AUC: 0.71816
# CV: 010, Epoch: 023, Val Loss: 28.30220, Val ACC: 0.64085,Val AUC: 0.67826, Test ACC: 0.63694, Test F1: 0.61745, TEST SPE: 0.71053, TEST SEN: 0.56790, TEST AUC: 0.69574
# CV: 010, Epoch: 024, Val Loss: 26.67184, Val ACC: 0.61972,Val AUC: 0.71661, Test ACC: 0.63694, Test F1: 0.57143, TEST SPE: 0.81579, TEST SEN: 0.46914, TEST AUC: 0.69120
# CV: 010, Epoch: 025, Val Loss: 23.56920, Val ACC: 0.64789,Val AUC: 0.71979, Test ACC: 0.58599, Test F1: 0.55782, TEST SPE: 0.67105, TEST SEN: 0.50617, TEST AUC: 0.67771
# CV: 010, Epoch: 026, Val Loss: 29.11375, Val ACC: 0.61972,Val AUC: 0.68124, Test ACC: 0.62420, Test F1: 0.65896, TEST SPE: 0.53947, TEST SEN: 0.70370, TEST AUC: 0.71442
# CV: 010, Epoch: 027, Val Loss: 75.48032, Val ACC: 0.56338,Val AUC: 0.59420, Test ACC: 0.55414, Test F1: 0.69565, TEST SPE: 0.09211, TEST SEN: 0.98765, TEST AUC: 0.71735
# CV: 010, Epoch: 028, Val Loss: 47.76963, Val ACC: 0.54930,Val AUC: 0.54630, Test ACC: 0.61783, Test F1: 0.65116, TEST SPE: 0.53947, TEST SEN: 0.69136, TEST AUC: 0.67057
# CV: 010, Epoch: 029, Val Loss: 81.72243, Val ACC: 0.52113,Val AUC: 0.74066, Test ACC: 0.52866, Test F1: 0.15909, TEST SPE: 1.00000, TEST SEN: 0.08642, TEST AUC: 0.60932
# CV: 010, Epoch: 030, Val Loss: 106.60867, Val ACC: 0.57746,Val AUC: 0.51957, Test ACC: 0.63057, Test F1: 0.71287, TEST SPE: 0.35526, TEST SEN: 0.88889, TEST AUC: 0.67844
# CV: 010, Epoch: 031, Val Loss: 51.40760, Val ACC: 0.60563,Val AUC: 0.73470, Test ACC: 0.55414, Test F1: 0.33962, TEST SPE: 0.90789, TEST SEN: 0.22222, TEST AUC: 0.61598
# CV: 010, Epoch: 032, Val Loss: 36.36715, Val ACC: 0.63380,Val AUC: 0.63315, Test ACC: 0.66242, Test F1: 0.72251, TEST SPE: 0.46053, TEST SEN: 0.85185, TEST AUC: 0.69997
# CV: 010, Epoch: 033, Val Loss: 50.81713, Val ACC: 0.54225,Val AUC: 0.77544, Test ACC: 0.54777, Test F1: 0.23656, TEST SPE: 0.98684, TEST SEN: 0.13580, TEST AUC: 0.72953
# CV: 010, Epoch: 034, Val Loss: 31.59719, Val ACC: 0.63380,Val AUC: 0.71025, Test ACC: 0.62420, Test F1: 0.68108, TEST SPE: 0.46053, TEST SEN: 0.77778, TEST AUC: 0.70013
# CV: 010, Epoch: 035, Val Loss: 42.25771, Val ACC: 0.61972,Val AUC: 0.71403, Test ACC: 0.49682, Test F1: 0.59487, TEST SPE: 0.26316, TEST SEN: 0.71605, TEST AUC: 0.59243
# CV: 010, Epoch: 036, Val Loss: 78.27993, Val ACC: 0.50704,Val AUC: 0.70548, Test ACC: 0.54140, Test F1: 0.69231, TEST SPE: 0.05263, TEST SEN: 1.00000, TEST AUC: 0.61728
# CV: 010, Epoch: 037, Val Loss: 27.26194, Val ACC: 0.64789,Val AUC: 0.72913, Test ACC: 0.61783, Test F1: 0.58904, TEST SPE: 0.71053, TEST SEN: 0.53086, TEST AUC: 0.71426
# CV: 010, Epoch: 038, Val Loss: 120.43494, Val ACC: 0.52113,Val AUC: 0.58039, Test ACC: 0.51592, Test F1: 0.68067, TEST SPE: 0.00000, TEST SEN: 1.00000, TEST AUC: 0.64774
# CV: 010, Epoch: 039, Val Loss: 36.63191, Val ACC: 0.63380,Val AUC: 0.70807, Test ACC: 0.66879, Test F1: 0.61765, TEST SPE: 0.82895, TEST SEN: 0.51852, TEST AUC: 0.74220
# CV: 010, Epoch: 040, Val Loss: 31.29865, Val ACC: 0.69718,Val AUC: 0.74583, Test ACC: 0.66242, Test F1: 0.73892, TEST SPE: 0.38158, TEST SEN: 0.92593, TEST AUC: 0.72775
# CV: 010, Epoch: 041, Val Loss: 29.85704, Val ACC: 0.66901,Val AUC: 0.73311, Test ACC: 0.59236, Test F1: 0.62791, TEST SPE: 0.51316, TEST SEN: 0.66667, TEST AUC: 0.60754
# CV: 010, Epoch: 042, Val Loss: 40.85013, Val ACC: 0.64789,Val AUC: 0.71602, Test ACC: 0.50955, Test F1: 0.56983, TEST SPE: 0.38158, TEST SEN: 0.62963, TEST AUC: 0.58609
# CV: 010, Epoch: 043, Val Loss: 49.70359, Val ACC: 0.59859,Val AUC: 0.72615, Test ACC: 0.58599, Test F1: 0.36893, TEST SPE: 0.96053, TEST SEN: 0.23457, TEST AUC: 0.70776
# CV: 010, Epoch: 044, Val Loss: 50.14010, Val ACC: 0.64085,Val AUC: 0.67428, Test ACC: 0.59873, Test F1: 0.70698, TEST SPE: 0.23684, TEST SEN: 0.93827, TEST AUC: 0.71475
# CV: 010, Epoch: 045, Val Loss: 63.33340, Val ACC: 0.61268,Val AUC: 0.65382, Test ACC: 0.62420, Test F1: 0.71770, TEST SPE: 0.30263, TEST SEN: 0.92593, TEST AUC: 0.72320
# CV: 010, Epoch: 046, Val Loss: 29.76275, Val ACC: 0.71831,Val AUC: 0.73052, Test ACC: 0.65605, Test F1: 0.72449, TEST SPE: 0.42105, TEST SEN: 0.87654, TEST AUC: 0.70127
# CV: 010, Epoch: 047, Val Loss: 34.27473, Val ACC: 0.64085,Val AUC: 0.73847, Test ACC: 0.64968, Test F1: 0.70588, TEST SPE: 0.47368, TEST SEN: 0.81481, TEST AUC: 0.73083
# CV: 010, Epoch: 048, Val Loss: 79.55934, Val ACC: 0.55634,Val AUC: 0.61953, Test ACC: 0.57325, Test F1: 0.70485, TEST SPE: 0.13158, TEST SEN: 0.98765, TEST AUC: 0.66943
# CV: 010, Epoch: 049, Val Loss: 42.67630, Val ACC: 0.58451,Val AUC: 0.66335, Test ACC: 0.68153, Test F1: 0.66667, TEST SPE: 0.75000, TEST SEN: 0.61728, TEST AUC: 0.71491
# CV: 010, Epoch: 050, Val Loss: 26.80542, Val ACC: 0.69014,Val AUC: 0.73410, Test ACC: 0.61146, Test F1: 0.66298, TEST SPE: 0.47368, TEST SEN: 0.74074, TEST AUC: 0.65838

# %%
print("Corresponding to minimum val loss")
eval_df1 = pd.DataFrame(eval_metrics1)
eval_df1.columns = ['SEN', 'SPE', 'ACC','F1', 'AUC-ROC']
eval_df1.index = ['Fold_%02i' % (i + 1) for i in range(skf.n_splits)]
print(eval_df1)
print('Average Sensitivity: %.4f±%.4f' % (eval_metrics1[:, 0].mean(), eval_metrics1[:, 0].std()))
print('Average Specificity: %.4f±%.4f' % (eval_metrics1[:, 1].mean(), eval_metrics1[:, 1].std()))
print('Average Accuracy: %.4f±%.4f' % (eval_metrics1[:, 2].mean(), eval_metrics1[:, 2].std()))
print('Average F1: %.4f±%.4f' % (eval_metrics1[:, 3].mean(), eval_metrics1[:, 3].std()))
print('Average AUC-ROC: %.4f±%.4f' % (eval_metrics1[:, 4].mean(), eval_metrics1[:, 4].std()))


print("\nCorresponding to best test acc")
eval_df2 = pd.DataFrame(eval_metrics2)
eval_df2.columns = ['SEN', 'SPE', 'ACC','F1', 'AUC-ROC']
eval_df2.index = ['Fold_%02i' % (i + 1) for i in range(skf.n_splits)]
print(eval_df2)
print('Average Sensitivity: %.4f±%.4f' % (eval_metrics2[:, 0].mean(), eval_metrics2[:, 0].std()))
print('Average Specificity: %.4f±%.4f' % (eval_metrics2[:, 1].mean(), eval_metrics2[:, 1].std()))
print('Average Accuracy: %.4f±%.4f' % (eval_metrics2[:, 2].mean(), eval_metrics2[:, 2].std()))
print('Average F1: %.4f±%.4f' % (eval_metrics2[:, 3].mean(), eval_metrics2[:, 3].std()))
print('Average AUC-ROC: %.4f±%.4f' % (eval_metrics2[:, 4].mean(), eval_metrics2[:, 4].std()))

print("\nCorresponding to maxm val acc")
eval_df3 = pd.DataFrame(eval_metrics3)
eval_df3.columns = ['SEN', 'SPE', 'ACC','F1', 'AUC-ROC']
eval_df3.index = ['Fold_%02i' % (i + 1) for i in range(skf.n_splits)]
print(eval_df3)
print('Average Sensitivity: %.4f±%.4f' % (eval_metrics3[:, 0].mean(), eval_metrics3[:, 0].std()))
print('Average Specificity: %.4f±%.4f' % (eval_metrics3[:, 1].mean(), eval_metrics3[:, 1].std()))
print('Average Accuracy: %.4f±%.4f' % (eval_metrics3[:, 2].mean(), eval_metrics3[:, 2].std()))
print('Average F1: %.4f±%.4f' % (eval_metrics3[:, 3].mean(), eval_metrics3[:, 3].std()))
print('Average AUC-ROC: %.4f±%.4f' % (eval_metrics3[:, 4].mean(), eval_metrics3[:, 4].std()))

print("\nCorresponding to maxm val AUC")
eval_df4 = pd.DataFrame(eval_metrics4)
eval_df4.columns = ['SEN', 'SPE', 'ACC','F1', 'AUC-ROC']
eval_df4.index = ['Fold_%02i' % (i + 1) for i in range(skf.n_splits)]
print(eval_df4)
print('Average Sensitivity: %.4f±%.4f' % (eval_metrics4[:, 0].mean(), eval_metrics4[:, 0].std()))
print('Average Specificity: %.4f±%.4f' % (eval_metrics4[:, 1].mean(), eval_metrics4[:, 1].std()))
print('Average Accuracy: %.4f±%.4f' % (eval_metrics4[:, 2].mean(), eval_metrics4[:, 2].std()))
print('Average F1: %.4f±%.4f' % (eval_metrics4[:, 3].mean(), eval_metrics4[:, 3].std()))
print('Average AUC-ROC: %.4f±%.4f' % (eval_metrics4[:, 4].mean(), eval_metrics4[:, 4].std()))
# Out:
# Corresponding to minimum val loss
#               SEN       SPE       ACC        F1   AUC-ROC
# Fold_01  0.695122  0.573333  0.636943  0.666667  0.682602
# Fold_02  0.878049  0.413333  0.656051  0.727273  0.709919
# Fold_03  0.719512  0.733333  0.726115  0.732919  0.758374
# Fold_04  0.536585  0.786667  0.656051  0.619718  0.768130
# Fold_05  0.728395  0.513158  0.624204  0.666667  0.708090
# Fold_06  0.765432  0.592105  0.681529  0.712644  0.737979
# Fold_07  0.679012  0.605263  0.643312  0.662651  0.684535
# Fold_08  0.641975  0.631579  0.636943  0.645963  0.721085
# Fold_09  0.716049  0.671053  0.694268  0.707317  0.752924
# Fold_10  0.777778  0.486842  0.636943  0.688525  0.701105
# Average Sensitivity: 0.7138±0.0849
# Average Specificity: 0.6007±0.1071
# Average Accuracy: 0.6592±0.0303
# Average F1: 0.6830±0.0350
# Average AUC-ROC: 0.7225±0.0290
#
# Corresponding to best test acc
#               SEN       SPE       ACC        F1   AUC-ROC
# Fold_01  0.731707  0.586667  0.662420  0.693642  0.678049
# Fold_02  0.670732  0.733333  0.700637  0.700637  0.732683
# Fold_03  0.719512  0.733333  0.726115  0.732919  0.758374
# Fold_04  0.743902  0.720000  0.732484  0.743902  0.782114
# Fold_05  0.716049  0.657895  0.687898  0.703030  0.763483
# Fold_06  0.691358  0.776316  0.732484  0.727273  0.816439
# Fold_07  0.654321  0.657895  0.656051  0.662500  0.698506
# Fold_08  0.629630  0.750000  0.687898  0.675497  0.767706
# Fold_09  0.802469  0.671053  0.738854  0.760234  0.814165
# Fold_10  0.555556  0.828947  0.687898  0.647482  0.769493
# Average Sensitivity: 0.6915±0.0650
# Average Specificity: 0.7115±0.0659
# Average Accuracy: 0.7013±0.0284
# Average F1: 0.7047±0.0346
# Average AUC-ROC: 0.7581±0.0424
#
# Corresponding to maxm val acc
#               SEN       SPE       ACC        F1   AUC-ROC
# Fold_01  0.695122  0.573333  0.636943  0.666667  0.682602
# Fold_02  0.804878  0.453333  0.636943  0.698413  0.728780
# Fold_03  0.914634  0.426667  0.681529  0.750000  0.736911
# Fold_04  0.804878  0.466667  0.643312  0.702128  0.744553
# Fold_05  0.827160  0.513158  0.675159  0.724324  0.719136
# Fold_06  0.617284  0.763158  0.687898  0.671141  0.773229
# Fold_07  0.654321  0.657895  0.656051  0.662500  0.698506
# Fold_08  0.641975  0.631579  0.636943  0.645963  0.721085
# Fold_09  0.716049  0.671053  0.694268  0.707317  0.752924
# Fold_10  0.876543  0.421053  0.656051  0.724490  0.701267
# Average Sensitivity: 0.7553±0.0987
# Average Specificity: 0.5578±0.1131
# Average Accuracy: 0.6605±0.0213
# Average F1: 0.6953±0.0313
# Average AUC-ROC: 0.7259±0.0260
#
# Corresponding to maxm val AUC
#               SEN       SPE       ACC        F1   AUC-ROC
# Fold_01  0.756098  0.493333  0.630573  0.681319  0.685203
# Fold_02  0.024390  0.973333  0.477707  0.046512  0.721626
# Fold_03  0.963415  0.146667  0.573248  0.702222  0.732846
# Fold_04  0.573171  0.813333  0.687898  0.657343  0.745691
# Fold_05  0.407407  0.855263  0.624204  0.528000  0.714912
# Fold_06  0.975309  0.355263  0.675159  0.755981  0.811891
# Fold_07  0.024691  1.000000  0.496815  0.048193  0.707115
# Fold_08  0.098765  0.986842  0.528662  0.177778  0.739929
# Fold_09  0.419753  0.947368  0.675159  0.571429  0.821313
# Fold_10  0.345679  0.723684  0.528662  0.430769  0.666829
# Average Sensitivity: 0.4589±0.3386
# Average Specificity: 0.7295±0.2837
# Average Accuracy: 0.5898±0.0748
# Average F1: 0.4600±0.2593
# Average AUC-ROC: 0.7347±0.0469
